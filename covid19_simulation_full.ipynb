# %% [markdown]
# ## Baseline Code

# %%
# %load_ext line_profiler

# %%
import numpy as np
from tqdm import tqdm
import argparse
from multiprocessing import cpu_count
from functools import partial
from multiprocessing.pool import Pool
import pandas as pd
import optparse  
# Matplotlib doesn't play nicely with multiprocessing, so
# we have to create a separate graphing function & import matplotlib inside of that.
def graphing_function(args, days, norms):
    import matplotlib.pyplot as plt
    susceptible_pop_norm, infected_pop_norm, recovered_pop_norm = norms
    # plot results and save the plot
    fig = plt.figure()
    ax = plt.axes()
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.plot(np.arange(days), susceptible_pop_norm, label='Susceptible', color='#4aa5f0', linewidth=2)
    ax.plot(np.arange(days), infected_pop_norm, label='Infected', color='#f03737', linewidth=2)
    ax.plot(np.arange(days), recovered_pop_norm, label='Recovered', color='#82e88a', linewidth=2)
    ax.legend(frameon=False)
    ax.set_xlabel("Days")
    ax.set_ylabel("Share of Population")
    if 'fig_name' in args:
        ax.figure.savefig('figures/' + args.fig_name + '.png')
    else:
        ax.figure.savefig('figures/sir_plot.png')
    plt.close()
    
# Convenience function: access Python dict keys as dict.key instead of dict['key']
class objdict(dict):
    def __getattr__(self, name):
        if name in self:
            return self[name]
        else:
            raise AttributeError("No such attribute: " + name)

    def __setattr__(self, name, value):
        self[name] = value

    def __delattr__(self, name):
        if name in self:
            del self[name]
        else:
            raise AttributeError("No such attribute: " + name)
            
# Run n simulations in parallel: for each run, parameters are randomly sampled from an interval
# NOTE: Are these intervals reasonable?
def multiprocess(args):

    chunks = []
    num_procs = args.randomize
    for _ in range(num_procs):
        d = dict()
        d['origin_matrix_path'] = args.origin_matrix_path
        d['thresh1'] = np.random.randint(0, 350)
        d['thresh2'] = np.random.randint(d['thresh1'], 700)
        d['infection_magnitude'] = np.random.randint(5, 15)
        d['beta'] = 1.6
        d['gamma'] = 0.04
        d['public_trans'] = np.random.randint(1, 7) * 0.1
        d['days'] = 200
        d['fig_name'] = 'public_trans_{:0.1f}_({}, {})_inf_{}'.format(d['public_trans'], d['thresh1'], d['thresh2'], d['infection_magnitude'])
        d['pandas_loading'] = args.pandas_loading
        d = objdict(d)
        chunks.append(d)

    with Pool(num_procs) as p:
        p.map(covid_sim, chunks)

    p.join()

def covid_sim(args):
    # Read in origin-destination flow matrix
    if args.pandas_loading != 0:
        print("using pandas loading")
        OD = pd.read_csv('data/Yerevan_OD_coronavirus.csv', header=None, dtype=np.float64).to_numpy()
    else:
        OD = np.genfromtxt(args.origin_matrix_path, delimiter=',')

    # initialize the population vector from the origin-destination flow matrix
    N_k = np.abs(np.diagonal(OD) + OD.sum(axis=0) - OD.sum(axis=1))
    locs_len = len(N_k)                 # number of locations
    SIR = np.zeros(shape=(locs_len, 3)) # make a numpy array with 3 columns for keeping track of the S, I, R groups
    SIR[:,0] = N_k                      # initialize the S group with the respective populations
    thresh1 = args.thresh1
    thresh2 = args.thresh2

    first_infections = np.where((thresh1 <= SIR[:, 0]) & (SIR[:, 0] <= thresh2), np.random.randint(1, args.infection_magnitude), 0)   # for demo purposes, randomly introduce infections
    # NOTE: this is arbitrary but not actually random.... 
    SIR[:, 0] = SIR[:, 0] - first_infections
    SIR[:, 1] = SIR[:, 1] + first_infections                           # move infections to the I group

    # row normalize the SIR matrix for keeping track of group proportions
    row_sums = SIR.sum(axis=1)
    SIR_n = SIR / row_sums[:, np.newaxis]

    # initialize parameters
    beta = args.beta
    gamma = args.gamma
    public_trans = args.public_trans                                 # alpha
    R0 = beta/gamma
    beta_vec = np.random.gamma(1.6, 2, locs_len)
    gamma_vec = np.full(locs_len, gamma)
    public_trans_vec = np.full(locs_len, public_trans)

    # make copy of the SIR matrices 
    SIR_sim = SIR.copy()
    SIR_nsim = SIR_n.copy()

    # run model
    #print(SIR_sim.sum(axis=0).sum() == N_k.sum())
    infected_pop_norm = []
    susceptible_pop_norm = []
    recovered_pop_norm = []
    days = 100
    for time_step in tqdm(range(days)):
        infected_mat = np.array([SIR_nsim[:,1],]*locs_len).transpose()
        OD_infected = np.round(OD*infected_mat)
        inflow_infected = OD_infected.sum(axis=0)
        inflow_infected = np.round(inflow_infected*public_trans_vec)
        #print('total infected inflow: ', inflow_infected.sum())
        new_infect = beta_vec*SIR_sim[:, 0]*inflow_infected/(N_k + OD.sum(axis=0))
        new_recovered = gamma_vec*SIR_sim[:, 1]
        new_infect = np.where(new_infect>SIR_sim[:, 0], SIR_sim[:, 0], new_infect)
        SIR_sim[:, 0] = SIR_sim[:, 0] - new_infect
        SIR_sim[:, 1] = SIR_sim[:, 1] + new_infect - new_recovered
        SIR_sim[:, 2] = SIR_sim[:, 2] + new_recovered
        SIR_sim = np.where(SIR_sim<0,0,SIR_sim)
        # recompute the normalized SIR matrix
        row_sums = SIR_sim.sum(axis=1)
        SIR_nsim = SIR_sim / row_sums[:, np.newaxis]
        S = SIR_sim[:,0].sum()/N_k.sum()
        I = SIR_sim[:,1].sum()/N_k.sum()
        R = SIR_sim[:,2].sum()/N_k.sum()
        #print(S, I, R, (S+I+R)*N_k.sum(), N_k.sum())
        #print('\n')
        infected_pop_norm.append(I)
        susceptible_pop_norm.append(S)
        recovered_pop_norm.append(R)

    graphing_function(args, days, (susceptible_pop_norm, infected_pop_norm, recovered_pop_norm))

# %%
parser = argparse.ArgumentParser(description='COVID Simulator')
parser.add_argument('--randomize', type=int, default=0)
parser.add_argument('--origin-matrix-path', default='data/Yerevan_OD_coronavirus.csv')
parser.add_argument('--thresh1', type=int, default=0)
parser.add_argument('--thresh2', type=int, default=200)
parser.add_argument('--infection-magnitude', type=int, default=10)
parser.add_argument('--beta', type=float, default=1.6)
parser.add_argument('--gamma', type=float, default=0.04)
parser.add_argument('--public-trans', type=float, default=0.5)
parser.add_argument('--days', type=int, default=100)
parser.add_argument('--img-folder', default='figures/')
parser.add_argument('--pandas_loading', default = 0)
parser.add_argument('--fig_name', default="figure_1")
# Out:
# _StoreAction(option_strings=['--fig_name'], dest='fig_name', nargs=None, const=None, default='figure_1', type=None, choices=None, help=None, metavar=None)

# %%
args1 = parser.parse_args("--randomize 4 --gamma 0.05 --pandas_loading 0 --fig_name test".split())

# %%
# %lprun -f covid_sim covid_sim(args1)
# Out:
# using pandas loading
# 100%|██████████| 100/100 [00:04<00:00, 21.94it/s]

# %% [raw]
# Timer unit: 1e-06 s
#
# Total time: 8.59509 s
# File: /Users/sree/.ipython/cython/_cython_magic_0b64d5c368a9ff889278efa98ff35d4c.pyx
# Function: covid_sim at line 78
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     78                                           def covid_sim(args):
#     79                                               # Read in origin-destination flow matrix
#     80         1          3.0      3.0      0.0      if args.pandas_loading != 0:
#     81                                                   OD = pd.read_csv('data/Yerevan_OD_coronavirus.csv', header=None, dtype=np.float64).to_numpy()
#     82                                               else:
#     83         1    4176730.0 4176730.0     48.6          OD = np.genfromtxt(args.origin_matrix_path, delimiter=',')
#     84
#     85                                               # initialize the population vector from the origin-destination flow matrix
#     86         1       5118.0   5118.0      0.1      N_k = np.abs(np.diagonal(OD) + OD.sum(axis=0) - OD.sum(axis=1))
#     87         1          2.0      2.0      0.0      locs_len = len(N_k)                 # number of locations
#     88         1         32.0     32.0      0.0      SIR = np.zeros(shape=(locs_len, 3)) # make a numpy array with 3 columns for keeping track of the S, I, R groups
#     89         1          6.0      6.0      0.0      SIR[:,0] = N_k                      # initialize the S group with the respective populations
#     90         1          2.0      2.0      0.0      thresh1 = args.thresh1
#     91         1          1.0      1.0      0.0      thresh2 = args.thresh2
#     92
#     93         1         48.0     48.0      0.0      first_infections = np.where((thresh1 <= SIR[:, 0]) & (SIR[:, 0] <= thresh2), np.random.randint(1, args.infection_magnitude), 0)   # for demo purposes, randomly introduce infections
#     94                                               # NOTE: this is arbitrary but not actually random....
#     95         1         11.0     11.0      0.0      SIR[:, 0] = SIR[:, 0] - first_infections
#     96         1          8.0      8.0      0.0      SIR[:, 1] = SIR[:, 1] + first_infections                           # move infections to the I group
#     97
#     98                                               # row normalize the SIR matrix for keeping track of group proportions
#     99         1         49.0     49.0      0.0      row_sums = SIR.sum(axis=1)
#    100         1         93.0     93.0      0.0      SIR_n = SIR / row_sums[:, np.newaxis]
#    101
#    102                                               # initialize parameters
#    103         1          1.0      1.0      0.0      beta = args.beta
#    104         1          1.0      1.0      0.0      gamma = args.gamma
#    105         1          1.0      1.0      0.0      public_trans = args.public_trans                                 # alpha
#    106         1          1.0      1.0      0.0      R0 = beta/gamma
#    107         1        122.0    122.0      0.0      beta_vec = np.random.gamma(1.6, 2, locs_len)
#    108         1         14.0     14.0      0.0      gamma_vec = np.full(locs_len, gamma)
#    109         1          6.0      6.0      0.0      public_trans_vec = np.full(locs_len, public_trans)
#    110
#    111                                               # make copy of the SIR matrices
#    112         1          5.0      5.0      0.0      SIR_sim = SIR.copy()
#    113         1         24.0     24.0      0.0      SIR_nsim = SIR_n.copy()
#    114
#    115                                               # run model
#    116                                               #print(SIR_sim.sum(axis=0).sum() == N_k.sum())
#    117         1          1.0      1.0      0.0      infected_pop_norm = []
#    118         1          0.0      0.0      0.0      susceptible_pop_norm = []
#    119         1          1.0      1.0      0.0      recovered_pop_norm = []
#    120         1          0.0      0.0      0.0      days = 100
#    121       101      25871.0    256.1      0.3      for time_step in tqdm(range(days)):
#    122       100     682786.0   6827.9      7.9          infected_mat = np.array([SIR_nsim[:,1],]*locs_len).transpose()
#    123       100    3017124.0  30171.2     35.1          OD_infected = np.round(OD*infected_mat)
#    124       100     267548.0   2675.5      3.1          inflow_infected = OD_infected.sum(axis=0)
#    125       100       3026.0     30.3      0.0          inflow_infected = np.round(inflow_infected*public_trans_vec)
#    126                                                   #print('total infected inflow: ', inflow_infected.sum())
#    127       100     298084.0   2980.8      3.5          new_infect = beta_vec*SIR_sim[:, 0]*inflow_infected/(N_k + OD.sum(axis=0))
#    128       100        975.0      9.8      0.0          new_recovered = gamma_vec*SIR_sim[:, 1]
#    129       100       1292.0     12.9      0.0          new_infect = np.where(new_infect>SIR_sim[:, 0], SIR_sim[:, 0], new_infect)
#    130       100        839.0      8.4      0.0          SIR_sim[:, 0] = SIR_sim[:, 0] - new_infect
#    131       100        793.0      7.9      0.0          SIR_sim[:, 1] = SIR_sim[:, 1] + new_infect - new_recovered
#    132       100        518.0      5.2      0.0          SIR_sim[:, 2] = SIR_sim[:, 2] + new_recovered
#    133       100       2023.0     20.2      0.0          SIR_sim = np.where(SIR_sim<0,0,SIR_sim)
#    134                                                   # recompute the normalized SIR matrix
#    135       100       4208.0     42.1      0.0          row_sums = SIR_sim.sum(axis=1)
#    136       100       1955.0     19.6      0.0          SIR_nsim = SIR_sim / row_sums[:, np.newaxis]
#    137       100       1397.0     14.0      0.0          S = SIR_sim[:,0].sum()/N_k.sum()
#    138       100        764.0      7.6      0.0          I = SIR_sim[:,1].sum()/N_k.sum()
#    139       100        744.0      7.4      0.0          R = SIR_sim[:,2].sum()/N_k.sum()
#    140                                                   #print(S, I, R, (S+I+R)*N_k.sum(), N_k.sum())
#    141                                                   #print('\n')
#    142       100         77.0      0.8      0.0          infected_pop_norm.append(I)
#    143       100         56.0      0.6      0.0          susceptible_pop_norm.append(S)
#    144       100         41.0      0.4      0.0          recovered_pop_norm.append(R)
#    145
#    146         1     102687.0 102687.0      1.2      graphing_function(args, days, (susceptible_pop_norm, infected_pop_norm, recovered_pop_norm))

# %%
# %lprun -f multiprocess multiprocess(args1)
# Out:
# ...
# 100%|██████████| 100/100 [00:09<00:00, 10.63it/s]

# %% [raw]
# Timer unit: 1e-06 s
#
# Total time: 18.1045 s
# File: <ipython-input-59-62d4b8f3ac30>
# Function: multiprocess at line 50
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     50                                           def multiprocess(args):
#     51
#     52         1          1.0      1.0      0.0      chunks = []
#     53         1          2.0      2.0      0.0      num_procs = args.randomize
#     54         5          5.0      1.0      0.0      for _ in range(num_procs):
#     55         4          2.0      0.5      0.0          d = dict()
#     56         4          4.0      1.0      0.0          d['origin_matrix_path'] = args.origin_matrix_path
#     57         4         67.0     16.8      0.0          d['thresh1'] = np.random.randint(0, 350)
#     58         4         13.0      3.2      0.0          d['thresh2'] = np.random.randint(d['thresh1'], 700)
#     59         4          9.0      2.2      0.0          d['infection_magnitude'] = np.random.randint(5, 15)
#     60         4          2.0      0.5      0.0          d['beta'] = 1.6
#     61         4          4.0      1.0      0.0          d['gamma'] = 0.04
#     62         4          9.0      2.2      0.0          d['public_trans'] = np.random.randint(1, 7) * 0.1
#     63         4          4.0      1.0      0.0          d['days'] = 200
#     64         4         37.0      9.2      0.0          d['fig_name'] = 'public_trans_{:0.1f}_({}, {})_inf_{}'.format(d['public_trans'], d['thresh1'], d['thresh2'], d['infection_magnitude'])
#     65         4          2.0      0.5      0.0          d['pandas_loading'] = args.pandas_loading
#     66         4          9.0      2.2      0.0          d = objdict(d)
#     67         4          3.0      0.8      0.0          chunks.append(d)
#     68
#     69         1      23891.0  23891.0      0.1      with Pool(num_procs) as p:
#     70         1   18080394.0 18080394.0     99.9          p.map(covid_sim, chunks)
#     71
#     72         1         38.0     38.0      0.0      p.join()

# %% [markdown]
# ### Line Profiler Analysis
#
# Using lprun, we see that most of the time is spent loading in the Origin-Destination flow matrix (accounts for 39.2% of the time) and computing the element-wise matrix multiplication OD\*infected_mat and rounding it (accounts for 43.8% of the time). Note that the matrix multiplication occurs in a for-loop that runs multiple times while the loading of the matrix occurs only once. The percentage of time needed to perform all of the matrix multiplications at all of the time steps is roughly the same as the time needed to load in the matrix. We will first focus on trying read the OD matrix faster.

# %% [markdown]
# ### Loading with Pandas

# %%
args2 = parser.parse_args("--randomize 4 --gamma 0.05 --pandas_loading 1".split())

# %%
# %lprun -f covid_sim covid_sim(args2)
# Out:
# using pandas loading
# 100%|██████████| 100/100 [00:02<00:00, 38.49it/s]

# %% [raw]
# Timer unit: 1e-06 s
#
# Total time: 3.10974 s
# File: <ipython-input-59-62d4b8f3ac30>
# Function: covid_sim at line 74
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     74                                           def covid_sim(args):
#     75                                               # Read in origin-destination flow matrix
#     76         1          3.0      3.0      0.0      if args.pandas_loading != 0:
#     77         1        162.0    162.0      0.0          print("using pandas loading")
#     78         1     501834.0 501834.0     16.1          OD = pd.read_csv('data/Yerevan_OD_coronavirus.csv', header=None, dtype=np.float64).to_numpy()
#     79                                               else:
#     80                                                   OD = np.genfromtxt(args.origin_matrix_path, delimiter=',')
#     81
#     82                                               # initialize the population vector from the origin-destination flow matrix
#     83         1       4326.0   4326.0      0.1      N_k = np.abs(np.diagonal(OD) + OD.sum(axis=0) - OD.sum(axis=1))
#     84         1          3.0      3.0      0.0      locs_len = len(N_k)                 # number of locations
#     85         1         13.0     13.0      0.0      SIR = np.zeros(shape=(locs_len, 3)) # make a numpy array with 3 columns for keeping track of the S, I, R groups
#     86         1          6.0      6.0      0.0      SIR[:,0] = N_k                      # initialize the S group with the respective populations
#     87         1          1.0      1.0      0.0      thresh1 = args.thresh1
#     88         1          1.0      1.0      0.0      thresh2 = args.thresh2
#     89
#     90         1         59.0     59.0      0.0      first_infections = np.where((thresh1 <= SIR[:, 0]) & (SIR[:, 0] <= thresh2), np.random.randint(1, args.infection_magnitude), 0)   # for demo purposes, randomly introduce infections
#     91                                               # NOTE: this is arbitrary but not actually random....
#     92         1         10.0     10.0      0.0      SIR[:, 0] = SIR[:, 0] - first_infections
#     93         1          8.0      8.0      0.0      SIR[:, 1] = SIR[:, 1] + first_infections                           # move infections to the I group
#     94
#     95                                               # row normalize the SIR matrix for keeping track of group proportions
#     96         1         37.0     37.0      0.0      row_sums = SIR.sum(axis=1)
#     97         1         29.0     29.0      0.0      SIR_n = SIR / row_sums[:, np.newaxis]
#     98
#     99                                               # initialize parameters
#    100         1          1.0      1.0      0.0      beta = args.beta
#    101         1          1.0      1.0      0.0      gamma = args.gamma
#    102         1          1.0      1.0      0.0      public_trans = args.public_trans                                 # alpha
#    103         1          1.0      1.0      0.0      R0 = beta/gamma
#    104         1        112.0    112.0      0.0      beta_vec = np.random.gamma(1.6, 2, locs_len)
#    105         1         22.0     22.0      0.0      gamma_vec = np.full(locs_len, gamma)
#    106         1          6.0      6.0      0.0      public_trans_vec = np.full(locs_len, public_trans)
#    107
#    108                                               # make copy of the SIR matrices
#    109         1          5.0      5.0      0.0      SIR_sim = SIR.copy()
#    110         1          4.0      4.0      0.0      SIR_nsim = SIR_n.copy()
#    111
#    112                                               # run model
#    113                                               #print(SIR_sim.sum(axis=0).sum() == N_k.sum())
#    114         1          1.0      1.0      0.0      infected_pop_norm = []
#    115         1          1.0      1.0      0.0      susceptible_pop_norm = []
#    116         1          1.0      1.0      0.0      recovered_pop_norm = []
#    117         1          0.0      0.0      0.0      days = 100
#    118       101      18258.0    180.8      0.6      for time_step in tqdm(range(days)):
#    119       100     712816.0   7128.2     22.9          infected_mat = np.array([SIR_nsim[:,1],]*locs_len).transpose()
#    120       100    1286753.0  12867.5     41.4          OD_infected = np.round(OD*infected_mat)
#    121       100     209439.0   2094.4      6.7          inflow_infected = OD_infected.sum(axis=0)
#    122       100       3732.0     37.3      0.1          inflow_infected = np.round(inflow_infected*public_trans_vec)
#    123                                                   #print('total infected inflow: ', inflow_infected.sum())
#    124       100     225298.0   2253.0      7.2          new_infect = beta_vec*SIR_sim[:, 0]*inflow_infected/(N_k + OD.sum(axis=0))
#    125       100       1374.0     13.7      0.0          new_recovered = gamma_vec*SIR_sim[:, 1]
#    126       100       1760.0     17.6      0.1          new_infect = np.where(new_infect>SIR_sim[:, 0], SIR_sim[:, 0], new_infect)
#    127       100        990.0      9.9      0.0          SIR_sim[:, 0] = SIR_sim[:, 0] - new_infect
#    128       100        982.0      9.8      0.0          SIR_sim[:, 1] = SIR_sim[:, 1] + new_infect - new_recovered
#    129       100        669.0      6.7      0.0          SIR_sim[:, 2] = SIR_sim[:, 2] + new_recovered
#    130       100       2521.0     25.2      0.1          SIR_sim = np.where(SIR_sim<0,0,SIR_sim)
#    131                                                   # recompute the normalized SIR matrix
#    132       100       4986.0     49.9      0.2          row_sums = SIR_sim.sum(axis=1)
#    133       100       2297.0     23.0      0.1          SIR_nsim = SIR_sim / row_sums[:, np.newaxis]
#    134       100       1641.0     16.4      0.1          S = SIR_sim[:,0].sum()/N_k.sum()
#    135       100        925.0      9.2      0.0          I = SIR_sim[:,1].sum()/N_k.sum()
#    136       100        903.0      9.0      0.0          R = SIR_sim[:,2].sum()/N_k.sum()
#    137                                                   #print(S, I, R, (S+I+R)*N_k.sum(), N_k.sum())
#    138                                                   #print('\n')
#    139       100        189.0      1.9      0.0          infected_pop_norm.append(I)
#    140       100        108.0      1.1      0.0          susceptible_pop_norm.append(S)
#    141       100        144.0      1.4      0.0          recovered_pop_norm.append(R)
#    142
#    143         1     127306.0 127306.0      4.1      graphing_function(args, days, (susceptible_pop_norm, infected_pop_norm, recovered_pop_norm))

# %%
# %lprun -f multiprocess multiprocess(args2)
# Out:
# using pandas loading
# using pandas loading
# using pandas loading
# using pandas loading
# ...
# 100%|██████████| 100/100 [00:08<00:00, 10.50it/s]

# %% [raw]
# Timer unit: 1e-06 s
#
# Total time: 10.2466 s
# File: <ipython-input-59-62d4b8f3ac30>
# Function: multiprocess at line 50
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     50                                           def multiprocess(args):
#     51
#     52         1          2.0      2.0      0.0      chunks = []
#     53         1          2.0      2.0      0.0      num_procs = args.randomize
#     54         5          4.0      0.8      0.0      for _ in range(num_procs):
#     55         4          4.0      1.0      0.0          d = dict()
#     56         4          3.0      0.8      0.0          d['origin_matrix_path'] = args.origin_matrix_path
#     57         4         33.0      8.2      0.0          d['thresh1'] = np.random.randint(0, 350)
#     58         4          9.0      2.2      0.0          d['thresh2'] = np.random.randint(d['thresh1'], 700)
#     59         4          8.0      2.0      0.0          d['infection_magnitude'] = np.random.randint(5, 15)
#     60         4          2.0      0.5      0.0          d['beta'] = 1.6
#     61         4          4.0      1.0      0.0          d['gamma'] = 0.04
#     62         4         10.0      2.5      0.0          d['public_trans'] = np.random.randint(1, 7) * 0.1
#     63         4          3.0      0.8      0.0          d['days'] = 200
#     64         4         13.0      3.2      0.0          d['fig_name'] = 'public_trans_{:0.1f}_({}, {})_inf_{}'.format(d['public_trans'], d['thresh1'], d['thresh2'], d['infection_magnitude'])
#     65         4          4.0      1.0      0.0          d['pandas_loading'] = args.pandas_loading
#     66         4          6.0      1.5      0.0          d = objdict(d)
#     67         4          3.0      0.8      0.0          chunks.append(d)
#     68
#     69         1      33137.0  33137.0      0.3      with Pool(num_procs) as p:
#     70         1   10213316.0 10213316.0     99.7          p.map(covid_sim, chunks)
#     71
#     72         1         55.0     55.0      0.0      p.join()

# %% [markdown]
# ### Improving Matrix Multiplication - Cython

# %%
# %load_ext Cython

# %%
# %%cython
#
# # cython: profile=True
# # cython: linetrace=True
# # cython: binding=True
# # distutils: define_macros=CYTHON_TRACE_NOGIL=1
#
# import numpy as np
# from tqdm import tqdm
# import argparse
# from multiprocessing import cpu_count
# from functools import partial
# from multiprocessing.pool import Pool
# import pandas as pd
#
# def graphing_function(args, days, norms):
#     import matplotlib.pyplot as plt
#     susceptible_pop_norm, infected_pop_norm, recovered_pop_norm = norms
#     # plot results and save the plot
#     fig = plt.figure()
#     ax = plt.axes()
#     ax.spines['right'].set_visible(False)
#     ax.spines['top'].set_visible(False)
#     ax.spines['left'].set_visible(False)
#     ax.plot(np.arange(days), susceptible_pop_norm, label='Susceptible', color='#4aa5f0', linewidth=2)
#     ax.plot(np.arange(days), infected_pop_norm, label='Infected', color='#f03737', linewidth=2)
#     ax.plot(np.arange(days), recovered_pop_norm, label='Recovered', color='#82e88a', linewidth=2)
#     ax.legend(frameon=False)
#     ax.set_xlabel("Days")
#     ax.set_ylabel("Share of Population")
#     if 'fig_name' in args:
#         ax.figure.savefig('figures/' + args.fig_name + '.png')
#     else:
#         ax.figure.savefig('figures/sir_plot.png')
#     plt.close()
#
# # Convenience function: access Python dict keys as dict.key instead of dict['key']
# class objdict(dict):
#     def __getattr__(self, name):
#         if name in self:
#             return self[name]
#         else:
#             raise AttributeError("No such attribute: " + name)
#
#     def __setattr__(self, name, value):
#         self[name] = value
#
#     def __delattr__(self, name):
#         if name in self:
#             del self[name]
#         else:
#             raise AttributeError("No such attribute: " + name)
#
# # Run n simulations in parallel: for each run, parameters are randomly sampled from an interval
# # NOTE: Are these intervals reasonable?
# def multiprocess(args):
#
#     chunks = []
#     num_procs = args.randomize
#     for _ in range(num_procs):
#         d = dict()
#         d['origin_matrix_path'] = args.origin_matrix_path
#         d['thresh1'] = np.random.randint(0, 350)
#         d['thresh2'] = np.random.randint(d['thresh1'], 700)
#         d['infection_magnitude'] = np.random.randint(5, 15)
#         d['beta'] = 1.6
#         d['gamma'] = 0.04
#         d['public_trans'] = np.random.randint(1, 7) * 0.1
#         d['days'] = 200
#         d['fig_name'] = 'public_trans_{:0.1f}_({}, {})_inf_{}'.format(d['public_trans'], d['thresh1'], d['thresh2'], d['infection_magnitude'])
#         d['pandas_loading'] = args.pandas_loading
#         d = objdict(d)
#         chunks.append(d)
#
#     with Pool(num_procs) as p:
#         p.map(covid_sim, chunks)
#
#     p.join()
#
# def covid_sim(args):
#     # Read in origin-destination flow matrix
#     if args.pandas_loading != 0:
#         OD = pd.read_csv('data/Yerevan_OD_coronavirus.csv', header=None, dtype=np.float64).to_numpy()
#     else:
#         OD = np.genfromtxt(args.origin_matrix_path, delimiter=',')
#
#     # initialize the population vector from the origin-destination flow matrix
#     N_k = np.abs(np.diagonal(OD) + OD.sum(axis=0) - OD.sum(axis=1))
#     locs_len = len(N_k)                 # number of locations
#     SIR = np.zeros(shape=(locs_len, 3)) # make a numpy array with 3 columns for keeping track of the S, I, R groups
#     SIR[:,0] = N_k                      # initialize the S group with the respective populations
#     thresh1 = args.thresh1
#     thresh2 = args.thresh2
#
#     first_infections = np.where((thresh1 <= SIR[:, 0]) & (SIR[:, 0] <= thresh2), np.random.randint(1, args.infection_magnitude), 0)   # for demo purposes, randomly introduce infections
#     # NOTE: this is arbitrary but not actually random....
#     SIR[:, 0] = SIR[:, 0] - first_infections
#     SIR[:, 1] = SIR[:, 1] + first_infections                           # move infections to the I group
#
#     # row normalize the SIR matrix for keeping track of group proportions
#     row_sums = SIR.sum(axis=1)
#     SIR_n = SIR / row_sums[:, np.newaxis]
#
#     # initialize parameters
#     beta = args.beta
#     gamma = args.gamma
#     public_trans = args.public_trans                                 # alpha
#     R0 = beta/gamma
#     beta_vec = np.random.gamma(1.6, 2, locs_len)
#     gamma_vec = np.full(locs_len, gamma)
#     public_trans_vec = np.full(locs_len, public_trans)
#
#     # make copy of the SIR matrices
#     SIR_sim = SIR.copy()
#     SIR_nsim = SIR_n.copy()
#
#     # run model
#     #print(SIR_sim.sum(axis=0).sum() == N_k.sum())
#     infected_pop_norm = []
#     susceptible_pop_norm = []
#     recovered_pop_norm = []
#     days = 100
#     for time_step in tqdm(range(days)):
#         infected_mat = np.array([SIR_nsim[:,1],]*locs_len).transpose()
#         OD_infected = np.round(OD*infected_mat)
#         inflow_infected = OD_infected.sum(axis=0)
#         inflow_infected = np.round(inflow_infected*public_trans_vec)
#         #print('total infected inflow: ', inflow_infected.sum())
#         new_infect = beta_vec*SIR_sim[:, 0]*inflow_infected/(N_k + OD.sum(axis=0))
#         new_recovered = gamma_vec*SIR_sim[:, 1]
#         new_infect = np.where(new_infect>SIR_sim[:, 0], SIR_sim[:, 0], new_infect)
#         SIR_sim[:, 0] = SIR_sim[:, 0] - new_infect
#         SIR_sim[:, 1] = SIR_sim[:, 1] + new_infect - new_recovered
#         SIR_sim[:, 2] = SIR_sim[:, 2] + new_recovered
#         SIR_sim = np.where(SIR_sim<0,0,SIR_sim)
#         # recompute the normalized SIR matrix
#         row_sums = SIR_sim.sum(axis=1)
#         SIR_nsim = SIR_sim / row_sums[:, np.newaxis]
#         S = SIR_sim[:,0].sum()/N_k.sum()
#         I = SIR_sim[:,1].sum()/N_k.sum()
#         R = SIR_sim[:,2].sum()/N_k.sum()
#         #print(S, I, R, (S+I+R)*N_k.sum(), N_k.sum())
#         #print('\n')
#         infected_pop_norm.append(I)
#         susceptible_pop_norm.append(S)
#         recovered_pop_norm.append(R)
#
#     graphing_function(args, days, (susceptible_pop_norm, infected_pop_norm, recovered_pop_norm))

# %%
# %lprun -f covid_sim covid_sim(args1)
# Out:
# 100%|██████████| 100/100 [00:04<00:00, 22.68it/s]

# %% [raw]
# Timer unit: 1e-06 s
#
# Total time: 8.21225 s
# File: /Users/sree/.ipython/cython/_cython_magic_0b64d5c368a9ff889278efa98ff35d4c.pyx
# Function: covid_sim at line 78
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     78                                           def covid_sim(args):
#     79                                               # Read in origin-destination flow matrix
#     80         1          9.0      9.0      0.0      if args.pandas_loading != 0:
#     81                                                   OD = pd.read_csv('data/Yerevan_OD_coronavirus.csv', header=None, dtype=np.float64).to_numpy()
#     82                                               else:
#     83         1    3688857.0 3688857.0     44.9          OD = np.genfromtxt(args.origin_matrix_path, delimiter=',')
#     84
#     85                                               # initialize the population vector from the origin-destination flow matrix
#     86         1       6459.0   6459.0      0.1      N_k = np.abs(np.diagonal(OD) + OD.sum(axis=0) - OD.sum(axis=1))
#     87         1          5.0      5.0      0.0      locs_len = len(N_k)                 # number of locations
#     88         1         34.0     34.0      0.0      SIR = np.zeros(shape=(locs_len, 3)) # make a numpy array with 3 columns for keeping track of the S, I, R groups
#     89         1          7.0      7.0      0.0      SIR[:,0] = N_k                      # initialize the S group with the respective populations
#     90         1          2.0      2.0      0.0      thresh1 = args.thresh1
#     91         1          1.0      1.0      0.0      thresh2 = args.thresh2
#     92
#     93         1         70.0     70.0      0.0      first_infections = np.where((thresh1 <= SIR[:, 0]) & (SIR[:, 0] <= thresh2), np.random.randint(1, args.infection_magnitude), 0)   # for demo purposes, randomly introduce infections
#     94                                               # NOTE: this is arbitrary but not actually random....
#     95         1         11.0     11.0      0.0      SIR[:, 0] = SIR[:, 0] - first_infections
#     96         1          8.0      8.0      0.0      SIR[:, 1] = SIR[:, 1] + first_infections                           # move infections to the I group
#     97
#     98                                               # row normalize the SIR matrix for keeping track of group proportions
#     99         1         50.0     50.0      0.0      row_sums = SIR.sum(axis=1)
#    100         1         76.0     76.0      0.0      SIR_n = SIR / row_sums[:, np.newaxis]
#    101
#    102                                               # initialize parameters
#    103         1          1.0      1.0      0.0      beta = args.beta
#    104         1          0.0      0.0      0.0      gamma = args.gamma
#    105         1          0.0      0.0      0.0      public_trans = args.public_trans                                 # alpha
#    106         1          0.0      0.0      0.0      R0 = beta/gamma
#    107         1        128.0    128.0      0.0      beta_vec = np.random.gamma(1.6, 2, locs_len)
#    108         1         17.0     17.0      0.0      gamma_vec = np.full(locs_len, gamma)
#    109         1          6.0      6.0      0.0      public_trans_vec = np.full(locs_len, public_trans)
#    110
#    111                                               # make copy of the SIR matrices
#    112         1          4.0      4.0      0.0      SIR_sim = SIR.copy()
#    113         1         26.0     26.0      0.0      SIR_nsim = SIR_n.copy()
#    114
#    115                                               # run model
#    116                                               #print(SIR_sim.sum(axis=0).sum() == N_k.sum())
#    117         1          1.0      1.0      0.0      infected_pop_norm = []
#    118         1          0.0      0.0      0.0      susceptible_pop_norm = []
#    119         1          0.0      0.0      0.0      recovered_pop_norm = []
#    120         1          0.0      0.0      0.0      days = 100
#    121       101      25867.0    256.1      0.3      for time_step in tqdm(range(days)):
#    122       100     698302.0   6983.0      8.5          infected_mat = np.array([SIR_nsim[:,1],]*locs_len).transpose()
#    123       100    3090922.0  30909.2     37.6          OD_infected = np.round(OD*infected_mat)
#    124       100     273356.0   2733.6      3.3          inflow_infected = OD_infected.sum(axis=0)
#    125       100       3200.0     32.0      0.0          inflow_infected = np.round(inflow_infected*public_trans_vec)
#    126                                                   #print('total infected inflow: ', inflow_infected.sum())
#    127       100     302036.0   3020.4      3.7          new_infect = beta_vec*SIR_sim[:, 0]*inflow_infected/(N_k + OD.sum(axis=0))
#    128       100       1063.0     10.6      0.0          new_recovered = gamma_vec*SIR_sim[:, 1]
#    129       100       1340.0     13.4      0.0          new_infect = np.where(new_infect>SIR_sim[:, 0], SIR_sim[:, 0], new_infect)
#    130       100        844.0      8.4      0.0          SIR_sim[:, 0] = SIR_sim[:, 0] - new_infect
#    131       100        822.0      8.2      0.0          SIR_sim[:, 1] = SIR_sim[:, 1] + new_infect - new_recovered
#    132       100        539.0      5.4      0.0          SIR_sim[:, 2] = SIR_sim[:, 2] + new_recovered
#    133       100       2316.0     23.2      0.0          SIR_sim = np.where(SIR_sim<0,0,SIR_sim)
#    134                                                   # recompute the normalized SIR matrix
#    135       100       4454.0     44.5      0.1          row_sums = SIR_sim.sum(axis=1)
#    136       100       2109.0     21.1      0.0          SIR_nsim = SIR_sim / row_sums[:, np.newaxis]
#    137       100       1524.0     15.2      0.0          S = SIR_sim[:,0].sum()/N_k.sum()
#    138       100        883.0      8.8      0.0          I = SIR_sim[:,1].sum()/N_k.sum()
#    139       100        795.0      8.0      0.0          R = SIR_sim[:,2].sum()/N_k.sum()
#    140                                                   #print(S, I, R, (S+I+R)*N_k.sum(), N_k.sum())
#    141                                                   #print('\n')
#    142       100         83.0      0.8      0.0          infected_pop_norm.append(I)
#    143       100         50.0      0.5      0.0          susceptible_pop_norm.append(S)
#    144       100         48.0      0.5      0.0          recovered_pop_norm.append(R)
#    145
#    146         1     105922.0 105922.0      1.3      graphing_function(args, days, (susceptible_pop_norm, infected_pop_norm, recovered_pop_norm))

# %%
# %lprun -f multiprocess multiprocess(args1)
# Out:
# ...
# 100%|██████████| 100/100 [00:09<00:00, 12.20it/s]

# %% [raw]
# Timer unit: 1e-06 s
#
# Total time: 17.0078 s
# File: /Users/sree/.ipython/cython/_cython_magic_c8876c9080e59fe67fde57fff97ff033.pyx
# Function: multiprocess at line 55
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     55                                           def multiprocess(args):
#     56
#     57         1          1.0      1.0      0.0      chunks = []
#     58         1          1.0      1.0      0.0      num_procs = args.randomize
#     59         5          2.0      0.4      0.0      for _ in range(num_procs):
#     60         4          1.0      0.2      0.0          d = dict()
#     61         4          2.0      0.5      0.0          d['origin_matrix_path'] = args.origin_matrix_path
#     62         4         24.0      6.0      0.0          d['thresh1'] = np.random.randint(0, 350)
#     63         4          8.0      2.0      0.0          d['thresh2'] = np.random.randint(d['thresh1'], 700)
#     64         4          6.0      1.5      0.0          d['infection_magnitude'] = np.random.randint(5, 15)
#     65         4          2.0      0.5      0.0          d['beta'] = 1.6
#     66         4          1.0      0.2      0.0          d['gamma'] = 0.04
#     67         4          7.0      1.8      0.0          d['public_trans'] = np.random.randint(1, 7) * 0.1
#     68         4          2.0      0.5      0.0          d['days'] = 200
#     69         4          7.0      1.8      0.0          d['fig_name'] = 'public_trans_{:0.1f}_({}, {})_inf_{}'.format(d['public_trans'], d['thresh1'], d['thresh2'], d['infection_magnitude'])
#     70         4          1.0      0.2      0.0          d['pandas_loading'] = args.pandas_loading
#     71         4          4.0      1.0      0.0          d = objdict(d)
#     72         4          1.0      0.2      0.0          chunks.append(d)
#     73
#     74         1      23288.0  23288.0      0.1      with Pool(num_procs) as p:
#     75         1   16983085.0 16983085.0     99.9          p.map(covid_sim, chunks)
#     76
#     77         1       1324.0   1324.0      0.0      p.join()

# %%
# %lprun -f covid_sim covid_sim(args2)
# Out:
# 100%|██████████| 100/100 [00:02<00:00, 30.80it/s]

# %% [raw]
# Timer unit: 1e-06 s
#
# Total time: 3.2209 s
# File: /Users/sree/.ipython/cython/_cython_magic_c8876c9080e59fe67fde57fff97ff033.pyx
# Function: covid_sim at line 79
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     79                                           def covid_sim(args):
#     80                                               # Read in origin-destination flow matrix
#     81         1          6.0      6.0      0.0      if args.pandas_loading != 0:
#     82         1     480476.0 480476.0     14.9          OD = pd.read_csv('data/Yerevan_OD_coronavirus.csv', header=None, dtype=np.float64).to_numpy()
#     83                                               else:
#     84                                                   OD = np.genfromtxt(args.origin_matrix_path, delimiter=',')
#     85
#     86                                               # initialize the population vector from the origin-destination flow matrix
#     87         1       4649.0   4649.0      0.1      N_k = np.abs(np.diagonal(OD) + OD.sum(axis=0) - OD.sum(axis=1))
#     88         1          5.0      5.0      0.0      locs_len = len(N_k)                 # number of locations
#     89         1          7.0      7.0      0.0      SIR = np.zeros(shape=(locs_len, 3)) # make a numpy array with 3 columns for keeping track of the S, I, R groups
#     90         1          6.0      6.0      0.0      SIR[:,0] = N_k                      # initialize the S group with the respective populations
#     91         1          5.0      5.0      0.0      thresh1 = args.thresh1
#     92         1          1.0      1.0      0.0      thresh2 = args.thresh2
#     93
#     94         1         53.0     53.0      0.0      first_infections = np.where((thresh1 <= SIR[:, 0]) & (SIR[:, 0] <= thresh2), np.random.randint(1, args.infection_magnitude), 0)   # for demo purposes, randomly introduce infections
#     95                                               # NOTE: this is arbitrary but not actually random....
#     96         1          9.0      9.0      0.0      SIR[:, 0] = SIR[:, 0] - first_infections
#     97         1          7.0      7.0      0.0      SIR[:, 1] = SIR[:, 1] + first_infections                           # move infections to the I group
#     98
#     99                                               # row normalize the SIR matrix for keeping track of group proportions
#    100         1         37.0     37.0      0.0      row_sums = SIR.sum(axis=1)
#    101         1         21.0     21.0      0.0      SIR_n = SIR / row_sums[:, np.newaxis]
#    102
#    103                                               # initialize parameters
#    104         1          3.0      3.0      0.0      beta = args.beta
#    105         1          3.0      3.0      0.0      gamma = args.gamma
#    106         1          0.0      0.0      0.0      public_trans = args.public_trans                                 # alpha
#    107         1          0.0      0.0      0.0      R0 = beta/gamma
#    108         1        112.0    112.0      0.0      beta_vec = np.random.gamma(1.6, 2, locs_len)
#    109         1         15.0     15.0      0.0      gamma_vec = np.full(locs_len, gamma)
#    110         1          5.0      5.0      0.0      public_trans_vec = np.full(locs_len, public_trans)
#    111
#    112                                               # make copy of the SIR matrices
#    113         1          4.0      4.0      0.0      SIR_sim = SIR.copy()
#    114         1         19.0     19.0      0.0      SIR_nsim = SIR_n.copy()
#    115
#    116                                               # run model
#    117                                               #print(SIR_sim.sum(axis=0).sum() == N_k.sum())
#    118         1          0.0      0.0      0.0      infected_pop_norm = []
#    119         1          0.0      0.0      0.0      susceptible_pop_norm = []
#    120         1          0.0      0.0      0.0      recovered_pop_norm = []
#    121         1          1.0      1.0      0.0      days = 100
#    122       101      19144.0    189.5      0.6      for time_step in tqdm(range(days)):
#    123       100     747322.0   7473.2     23.2          infected_mat = np.array([SIR_nsim[:,1],]*locs_len).transpose()
#    124       100    1305074.0  13050.7     40.5          OD_infected = np.round(OD*infected_mat)
#    125       100     232496.0   2325.0      7.2          inflow_infected = OD_infected.sum(axis=0)
#    126       100       3958.0     39.6      0.1          inflow_infected = np.round(inflow_infected*public_trans_vec)
#    127                                                   #print('total infected inflow: ', inflow_infected.sum())
#    128       100     240017.0   2400.2      7.5          new_infect = beta_vec*SIR_sim[:, 0]*inflow_infected/(N_k + OD.sum(axis=0))
#    129       100       1527.0     15.3      0.0          new_recovered = gamma_vec*SIR_sim[:, 1]
#    130       100       1565.0     15.7      0.0          new_infect = np.where(new_infect>SIR_sim[:, 0], SIR_sim[:, 0], new_infect)
#    131       100       1015.0     10.2      0.0          SIR_sim[:, 0] = SIR_sim[:, 0] - new_infect
#    132       100       1096.0     11.0      0.0          SIR_sim[:, 1] = SIR_sim[:, 1] + new_infect - new_recovered
#    133       100        752.0      7.5      0.0          SIR_sim[:, 2] = SIR_sim[:, 2] + new_recovered
#    134       100       2601.0     26.0      0.1          SIR_sim = np.where(SIR_sim<0,0,SIR_sim)
#    135                                                   # recompute the normalized SIR matrix
#    136       100       4869.0     48.7      0.2          row_sums = SIR_sim.sum(axis=1)
#    137       100       6221.0     62.2      0.2          SIR_nsim = SIR_sim / row_sums[:, np.newaxis]
#    138       100       1706.0     17.1      0.1          S = SIR_sim[:,0].sum()/N_k.sum()
#    139       100        897.0      9.0      0.0          I = SIR_sim[:,1].sum()/N_k.sum()
#    140       100        876.0      8.8      0.0          R = SIR_sim[:,2].sum()/N_k.sum()
#    141                                                   #print(S, I, R, (S+I+R)*N_k.sum(), N_k.sum())
#    142                                                   #print('\n')
#    143       100         70.0      0.7      0.0          infected_pop_norm.append(I)
#    144       100         95.0      0.9      0.0          susceptible_pop_norm.append(S)
#    145       100         51.0      0.5      0.0          recovered_pop_norm.append(R)
#    146
#    147         1     164103.0 164103.0      5.1      graphing_function(args, days, (susceptible_pop_norm, infected_pop_norm, recovered_pop_norm))

# %%
# %lprun -f multiprocess multiprocess(args2)
# Out:
# ...
# 100%|██████████| 100/100 [00:07<00:00, 13.27it/s]

# %% [raw]
# Timer unit: 1e-06 s
#
# Total time: 9.50979 s
# File: /Users/sree/.ipython/cython/_cython_magic_c8876c9080e59fe67fde57fff97ff033.pyx
# Function: multiprocess at line 55
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     55                                           def multiprocess(args):
#     56
#     57         1          1.0      1.0      0.0      chunks = []
#     58         1         20.0     20.0      0.0      num_procs = args.randomize
#     59         5         12.0      2.4      0.0      for _ in range(num_procs):
#     60         4          1.0      0.2      0.0          d = dict()
#     61         4         37.0      9.2      0.0          d['origin_matrix_path'] = args.origin_matrix_path
#     62         4        836.0    209.0      0.0          d['thresh1'] = np.random.randint(0, 350)
#     63         4         13.0      3.2      0.0          d['thresh2'] = np.random.randint(d['thresh1'], 700)
#     64         4         12.0      3.0      0.0          d['infection_magnitude'] = np.random.randint(5, 15)
#     65         4          3.0      0.8      0.0          d['beta'] = 1.6
#     66         4          3.0      0.8      0.0          d['gamma'] = 0.04
#     67         4          8.0      2.0      0.0          d['public_trans'] = np.random.randint(1, 7) * 0.1
#     68         4          0.0      0.0      0.0          d['days'] = 200
#     69         4         25.0      6.2      0.0          d['fig_name'] = 'public_trans_{:0.1f}_({}, {})_inf_{}'.format(d['public_trans'], d['thresh1'], d['thresh2'], d['infection_magnitude'])
#     70         4         11.0      2.8      0.0          d['pandas_loading'] = args.pandas_loading
#     71         4         20.0      5.0      0.0          d = objdict(d)
#     72         4          2.0      0.5      0.0          chunks.append(d)
#     73
#     74         1      36403.0  36403.0      0.4      with Pool(num_procs) as p:
#     75         1    9471063.0 9471063.0     99.6          p.map(covid_sim, chunks)
#     76
#     77         1       1323.0   1323.0      0.0      p.join()

# %% [markdown]
# We see a slight speed up when compiling with Cython without specifying the types of the variables.

# %% [markdown]
# ### Cython + Faster Matrix Loading + Removing tqdm

# %%
# %%cython
#
# # cython: profile=True
# # cython: linetrace=True
# # cython: binding=True
# # distutils: define_macros=CYTHON_TRACE_NOGIL=1
#
# import numpy as np
# from tqdm import tqdm
# import argparse
# from multiprocessing import cpu_count
# from functools import partial
# from multiprocessing.pool import Pool
# import pandas as pd
#
# def graphing_function(args, days, norms):
#     import matplotlib.pyplot as plt
#     susceptible_pop_norm, infected_pop_norm, recovered_pop_norm = norms
#     # plot results and save the plot
#     fig = plt.figure()
#     ax = plt.axes()
#     ax.spines['right'].set_visible(False)
#     ax.spines['top'].set_visible(False)
#     ax.spines['left'].set_visible(False)
#     ax.plot(np.arange(days), susceptible_pop_norm, label='Susceptible', color='#4aa5f0', linewidth=2)
#     ax.plot(np.arange(days), infected_pop_norm, label='Infected', color='#f03737', linewidth=2)
#     ax.plot(np.arange(days), recovered_pop_norm, label='Recovered', color='#82e88a', linewidth=2)
#     ax.legend(frameon=False)
#     ax.set_xlabel("Days")
#     ax.set_ylabel("Share of Population")
#     if 'fig_name' in args:
#         ax.figure.savefig('figures/' + args.fig_name + '.png')
#     else:
#         ax.figure.savefig('figures/sir_plot.png')
#     plt.close()
#
# # Convenience function: access Python dict keys as dict.key instead of dict['key']
# class objdict(dict):
#     def __getattr__(self, name):
#         if name in self:
#             return self[name]
#         else:
#             raise AttributeError("No such attribute: " + name)
#
#     def __setattr__(self, name, value):
#         self[name] = value
#
#     def __delattr__(self, name):
#         if name in self:
#             del self[name]
#         else:
#             raise AttributeError("No such attribute: " + name)
#
# # Run n simulations in parallel: for each run, parameters are randomly sampled from an interval
# # NOTE: Are these intervals reasonable?
# def multiprocess(args):
#
#     chunks = []
#     num_procs = args.randomize
#     for _ in range(num_procs):
#         d = dict()
#         d['origin_matrix_path'] = args.origin_matrix_path
#         d['thresh1'] = np.random.randint(0, 350)
#         d['thresh2'] = np.random.randint(d['thresh1'], 700)
#         d['infection_magnitude'] = np.random.randint(5, 15)
#         d['beta'] = 1.6
#         d['gamma'] = 0.04
#         d['public_trans'] = np.random.randint(1, 7) * 0.1
#         d['days'] = 200
#         d['fig_name'] = 'public_trans_{:0.1f}_({}, {})_inf_{}'.format(d['public_trans'], d['thresh1'], d['thresh2'], d['infection_magnitude'])
#         d['pandas_loading'] = args.pandas_loading
#         d = objdict(d)
#         chunks.append(d)
#
#     with Pool(num_procs) as p:
#         p.map(covid_sim, chunks)
#
#     p.join()
#
# def covid_sim(args):
#     # Read in origin-destination flow matrix
#     if args.pandas_loading != 0:
#         OD = pd.read_csv('data/Yerevan_OD_coronavirus.csv', header=None, dtype=np.float64).to_numpy()
#     else:
#         OD = np.genfromtxt(args.origin_matrix_path, delimiter=',')
#
#     # initialize the population vector from the origin-destination flow matrix
#     N_k = np.abs(np.diagonal(OD) + OD.sum(axis=0) - OD.sum(axis=1))
#     locs_len = len(N_k)                 # number of locations
#     SIR = np.zeros(shape=(locs_len, 3)) # make a numpy array with 3 columns for keeping track of the S, I, R groups
#     SIR[:,0] = N_k                      # initialize the S group with the respective populations
#     thresh1 = args.thresh1
#     thresh2 = args.thresh2
#
#     first_infections = np.where((thresh1 <= SIR[:, 0]) & (SIR[:, 0] <= thresh2), np.random.randint(1, args.infection_magnitude), 0)   # for demo purposes, randomly introduce infections
#     # NOTE: this is arbitrary but not actually random....
#     SIR[:, 0] = SIR[:, 0] - first_infections
#     SIR[:, 1] = SIR[:, 1] + first_infections                           # move infections to the I group
#
#     # row normalize the SIR matrix for keeping track of group proportions
#     row_sums = SIR.sum(axis=1)
#     SIR_n = SIR / row_sums[:, np.newaxis]
#
#     # initialize parameters
#     beta = args.beta
#     gamma = args.gamma
#     public_trans = args.public_trans                                 # alpha
#     R0 = beta/gamma
#     beta_vec = np.random.gamma(1.6, 2, locs_len)
#     gamma_vec = np.full(locs_len, gamma)
#     public_trans_vec = np.full(locs_len, public_trans)
#
#     # make copy of the SIR matrices
#     SIR_sim = SIR.copy()
#     SIR_nsim = SIR_n.copy()
#
#     # run model
#     #print(SIR_sim.sum(axis=0).sum() == N_k.sum())
#     infected_pop_norm = []
#     susceptible_pop_norm = []
#     recovered_pop_norm = []
#     days = 100
#     for time_step in range(days):
#         infected_mat = np.array([SIR_nsim[:,1],]*locs_len).transpose()
#         OD_infected = np.round(OD*infected_mat)
#         inflow_infected = OD_infected.sum(axis=0)
#         inflow_infected = np.round(inflow_infected*public_trans_vec)
#         #print('total infected inflow: ', inflow_infected.sum())
#         new_infect = beta_vec*SIR_sim[:, 0]*inflow_infected/(N_k + OD.sum(axis=0))
#         new_recovered = gamma_vec*SIR_sim[:, 1]
#         new_infect = np.where(new_infect>SIR_sim[:, 0], SIR_sim[:, 0], new_infect)
#         SIR_sim[:, 0] = SIR_sim[:, 0] - new_infect
#         SIR_sim[:, 1] = SIR_sim[:, 1] + new_infect - new_recovered
#         SIR_sim[:, 2] = SIR_sim[:, 2] + new_recovered
#         SIR_sim = np.where(SIR_sim<0,0,SIR_sim)
#         # recompute the normalized SIR matrix
#         row_sums = SIR_sim.sum(axis=1)
#         SIR_nsim = SIR_sim / row_sums[:, np.newaxis]
#         S = SIR_sim[:,0].sum()/N_k.sum()
#         I = SIR_sim[:,1].sum()/N_k.sum()
#         R = SIR_sim[:,2].sum()/N_k.sum()
#         #print(S, I, R, (S+I+R)*N_k.sum(), N_k.sum())
#         #print('\n')
#         infected_pop_norm.append(I)
#         susceptible_pop_norm.append(S)
#         recovered_pop_norm.append(R)
#
#     graphing_function(args, days, (susceptible_pop_norm, infected_pop_norm, recovered_pop_norm))

# %%
# %lprun -f covid_sim covid_sim(args2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-2f0164199017> in <module>
# ----> 1 get_ipython().run_line_magic('lprun', '-f covid_sim covid_sim(args2)')
#
# ~/miniconda3/envs/DS-1003/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2285                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2286             with self.builtin_trap:
# -> 2287                 result = fn(*args,**kwargs)
#    2288             return result
#    2289
#
# <decorator-gen-125> in lprun(self, parameter_s)
#
# ~/miniconda3/envs/DS-1003/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
# ...

# %% [raw]
# Timer unit: 1e-06 s
#
# Total time: 3.72659 s
# File: /Users/sree/.ipython/cython/_cython_magic_7ecbc5b6f71559e8835da2e8fb65841a.pyx
# Function: covid_sim at line 79
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     79                                           def covid_sim(args):
#     80                                               # Read in origin-destination flow matrix
#     81         1          8.0      8.0      0.0      if args.pandas_loading != 0:
#     82         1     506006.0 506006.0     13.6          OD = pd.read_csv('data/Yerevan_OD_coronavirus.csv', header=None, dtype=np.float64).to_numpy()
#     83                                               else:
#     84                                                   OD = np.genfromtxt(args.origin_matrix_path, delimiter=',')
#     85
#     86                                               # initialize the population vector from the origin-destination flow matrix
#     87         1       6876.0   6876.0      0.2      N_k = np.abs(np.diagonal(OD) + OD.sum(axis=0) - OD.sum(axis=1))
#     88         1          9.0      9.0      0.0      locs_len = len(N_k)                 # number of locations
#     89         1         11.0     11.0      0.0      SIR = np.zeros(shape=(locs_len, 3)) # make a numpy array with 3 columns for keeping track of the S, I, R groups
#     90         1          5.0      5.0      0.0      SIR[:,0] = N_k                      # initialize the S group with the respective populations
#     91         1          2.0      2.0      0.0      thresh1 = args.thresh1
#     92         1          0.0      0.0      0.0      thresh2 = args.thresh2
#     93
#     94         1         67.0     67.0      0.0      first_infections = np.where((thresh1 <= SIR[:, 0]) & (SIR[:, 0] <= thresh2), np.random.randint(1, args.infection_magnitude), 0)   # for demo purposes, randomly introduce infections
#     95                                               # NOTE: this is arbitrary but not actually random....
#     96         1         12.0     12.0      0.0      SIR[:, 0] = SIR[:, 0] - first_infections
#     97         1          8.0      8.0      0.0      SIR[:, 1] = SIR[:, 1] + first_infections                           # move infections to the I group
#     98
#     99                                               # row normalize the SIR matrix for keeping track of group proportions
#    100         1         42.0     42.0      0.0      row_sums = SIR.sum(axis=1)
#    101         1         21.0     21.0      0.0      SIR_n = SIR / row_sums[:, np.newaxis]
#    102
#    103                                               # initialize parameters
#    104         1          3.0      3.0      0.0      beta = args.beta
#    105         1          1.0      1.0      0.0      gamma = args.gamma
#    106         1          3.0      3.0      0.0      public_trans = args.public_trans                                 # alpha
#    107         1          1.0      1.0      0.0      R0 = beta/gamma
#    108         1        115.0    115.0      0.0      beta_vec = np.random.gamma(1.6, 2, locs_len)
#    109         1         17.0     17.0      0.0      gamma_vec = np.full(locs_len, gamma)
#    110         1          5.0      5.0      0.0      public_trans_vec = np.full(locs_len, public_trans)
#    111
#    112                                               # make copy of the SIR matrices
#    113         1          8.0      8.0      0.0      SIR_sim = SIR.copy()
#    114         1         32.0     32.0      0.0      SIR_nsim = SIR_n.copy()
#    115
#    116                                               # run model
#    117                                               #print(SIR_sim.sum(axis=0).sum() == N_k.sum())
#    118         1          1.0      1.0      0.0      infected_pop_norm = []
#    119         1          1.0      1.0      0.0      susceptible_pop_norm = []
#    120         1          1.0      1.0      0.0      recovered_pop_norm = []
#    121         1          0.0      0.0      0.0      days = 100
#    122         1          2.0      2.0      0.0      for time_step in range(days):
#    123       100     861143.0   8611.4     23.1          infected_mat = np.array([SIR_nsim[:,1],]*locs_len).transpose()
#    124       100    1700659.0  17006.6     45.6          OD_infected = np.round(OD*infected_mat)
#    125       100     256856.0   2568.6      6.9          inflow_infected = OD_infected.sum(axis=0)
#    126       100       5468.0     54.7      0.1          inflow_infected = np.round(inflow_infected*public_trans_vec)
#    127                                                   #print('total infected inflow: ', inflow_infected.sum())
#    128       100     256523.0   2565.2      6.9          new_infect = beta_vec*SIR_sim[:, 0]*inflow_infected/(N_k + OD.sum(axis=0))
#    129       100       1521.0     15.2      0.0          new_recovered = gamma_vec*SIR_sim[:, 1]
#    130       100       1681.0     16.8      0.0          new_infect = np.where(new_infect>SIR_sim[:, 0], SIR_sim[:, 0], new_infect)
#    131       100       1044.0     10.4      0.0          SIR_sim[:, 0] = SIR_sim[:, 0] - new_infect
#    132       100       1088.0     10.9      0.0          SIR_sim[:, 1] = SIR_sim[:, 1] + new_infect - new_recovered
#    133       100        737.0      7.4      0.0          SIR_sim[:, 2] = SIR_sim[:, 2] + new_recovered
#    134       100       2799.0     28.0      0.1          SIR_sim = np.where(SIR_sim<0,0,SIR_sim)
#    135                                                   # recompute the normalized SIR matrix
#    136       100       9461.0     94.6      0.3          row_sums = SIR_sim.sum(axis=1)
#    137       100       2561.0     25.6      0.1          SIR_nsim = SIR_sim / row_sums[:, np.newaxis]
#    138       100       1903.0     19.0      0.1          S = SIR_sim[:,0].sum()/N_k.sum()
#    139       100       1190.0     11.9      0.0          I = SIR_sim[:,1].sum()/N_k.sum()
#    140       100       1030.0     10.3      0.0          R = SIR_sim[:,2].sum()/N_k.sum()
#    141                                                   #print(S, I, R, (S+I+R)*N_k.sum(), N_k.sum())
#    142                                                   #print('\n')
#    143       100         94.0      0.9      0.0          infected_pop_norm.append(I)
#    144       100         72.0      0.7      0.0          susceptible_pop_norm.append(S)
#    145       100         71.0      0.7      0.0          recovered_pop_norm.append(R)
#    146
#    147         1     107431.0 107431.0      2.9      graphing_function(args, days, (susceptible_pop_norm, infected_pop_norm, recovered_pop_norm))

# %%
# %lprun -f multiprocess multiprocess(args2)

# %% [raw]
# Timer unit: 1e-06 s
#
# Total time: 7.70149 s
# File: /Users/sree/.ipython/cython/_cython_magic_7ecbc5b6f71559e8835da2e8fb65841a.pyx
# Function: multiprocess at line 55
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     55                                           def multiprocess(args):
#     56
#     57         1          1.0      1.0      0.0      chunks = []
#     58         1          1.0      1.0      0.0      num_procs = args.randomize
#     59         5          6.0      1.2      0.0      for _ in range(num_procs):
#     60         4          1.0      0.2      0.0          d = dict()
#     61         4          3.0      0.8      0.0          d['origin_matrix_path'] = args.origin_matrix_path
#     62         4         26.0      6.5      0.0          d['thresh1'] = np.random.randint(0, 350)
#     63         4          9.0      2.2      0.0          d['thresh2'] = np.random.randint(d['thresh1'], 700)
#     64         4          7.0      1.8      0.0          d['infection_magnitude'] = np.random.randint(5, 15)
#     65         4          0.0      0.0      0.0          d['beta'] = 1.6
#     66         4          2.0      0.5      0.0          d['gamma'] = 0.04
#     67         4          8.0      2.0      0.0          d['public_trans'] = np.random.randint(1, 7) * 0.1
#     68         4          0.0      0.0      0.0          d['days'] = 200
#     69         4          9.0      2.2      0.0          d['fig_name'] = 'public_trans_{:0.1f}_({}, {})_inf_{}'.format(d['public_trans'], d['thresh1'], d['thresh2'], d['infection_magnitude'])
#     70         4          2.0      0.5      0.0          d['pandas_loading'] = args.pandas_loading
#     71         4          3.0      0.8      0.0          d = objdict(d)
#     72         4          2.0      0.5      0.0          chunks.append(d)
#     73
#     74         1      31621.0  31621.0      0.4      with Pool(num_procs) as p:
#     75         1    7668310.0 7668310.0     99.6          p.map(covid_sim, chunks)
#     76
#     77         1       1481.0   1481.0      0.0      p.join()

# %% [markdown]
# ### Cython - Specifying Types - not working, need to use optparse. tried it but ran into some issues.

# %%
# %%cython
#
# # cython: profile=True
# # cython: linetrace=True
# # cython: binding=True
# # distutils: define_macros=CYTHON_TRACE_NOGIL=1
#
# import numpy as np
# from tqdm import tqdm
# import argparse
# from multiprocessing import cpu_count
# from functools import partial
# from multiprocessing.pool import Pool
# import pandas as pd
# cimport numpy as np
#
# def graphing_function(np.ndarray[np.float64_t, ndim=1] infected_pop_norm, np.ndarray[np.float64_t, ndim=1] susceptible_pop_norm, np.ndarray[np.float64_t, ndim=1] recovered_pop_norm, int days, fig_name):
#     import matplotlib.pyplot as plt
#     # plot results and save the plot
#     fig = plt.figure()
#     ax = plt.axes()
#     ax.spines['right'].set_visible(False)
#     ax.spines['top'].set_visible(False)
#     ax.spines['left'].set_visible(False)
#     ax.plot(np.arange(days), susceptible_pop_norm, label='Susceptible', color='#4aa5f0', linewidth=2)
#     ax.plot(np.arange(days), infected_pop_norm, label='Infected', color='#f03737', linewidth=2)
#     ax.plot(np.arange(days), recovered_pop_norm, label='Recovered', color='#82e88a', linewidth=2)
#     ax.legend(frameon=False)
#     ax.set_xlabel("Days")
#     ax.set_ylabel("Share of Population")
#     if fig_name:
#         ax.figure.savefig('figures/' + fig_name + '.png')
#     else:
#         ax.figure.savefig('figures/sir_plot.png')
#     plt.close()
#
# # Convenience function: access Python dict keys as dict.key instead of dict['key']
# class objdict(dict):
#     def __getattr__(self, name):
#         if name in self:
#             return self[name]
#         else:
#             raise AttributeError("No such attribute: " + name)
#
#     def __setattr__(self, name, value):
#         self[name] = value
#
#     def __delattr__(self, name):
#         if name in self:
#             del self[name]
#         else:
#             raise AttributeError("No such attribute: " + name)
#
# # Run n simulations in parallel: for each run, parameters are randomly sampled from an interval
# # NOTE: Are these intervals reasonable?
# def multiprocess(args):
#
#     chunks = []
#     num_procs = args.randomize
#     for _ in range(num_procs):
#         d = dict()
#         d['origin_matrix_path'] = args.origin_matrix_path
#         d['thresh1'] = np.random.randint(0, 350)
#         d['thresh2'] = np.random.randint(d['thresh1'], 700)
#         d['infection_magnitude'] = np.random.randint(5, 15)
#         d['beta'] = 1.6
#         d['gamma'] = 0.04
#         d['public_trans'] = np.random.randint(1, 7) * 0.1
#         d['days'] = 200
#         d['fig_name'] = 'public_trans_{:0.1f}_({}, {})_inf_{}'.format(d['public_trans'], d['thresh1'], d['thresh2'], d['infection_magnitude'])
#         d['pandas_loading'] = args.pandas_loading
#         d = objdict(d)
#         chunks.append(d)
#
#     with Pool(num_procs) as p:
#         p.map(covid_sim, chunks)
#
#     p.join()
#
# def covid_sim(args):
#     # Read in origin-destination flow matrix
#     cdef np.ndarray[np.float64_t, ndim=2] OD, SIR, SIR_n, SIR_sim, SIR_nsim, infected_mat, OD_infected
#     cdef np.ndarray[np.float64_t, ndim=1] N_k, first_infections, row_sums, beta_vec, gamma_vec, public_trans_vec, inflow_infected, new_infect, new_recovered
#     cdef int locs_len, time_step
#     cdef np.float64_t R0, S, I, R
#     cdef np.ndarray[np.float64_t, ndim=1] infected_pop_norm, susceptible_pop_norm, recovered_pop_norm
#
#     if args.pandas_loading != 0:
#         OD = pd.read_csv('data/Yerevan_OD_coronavirus.csv', header=None, dtype=np.float64).to_numpy()
#     else:
#         OD = np.genfromtxt(args.origin_matrix_path, delimiter=',')
#
#     # initialize the population vector from the origin-destination flow matrix
#     N_k = np.abs(np.diagonal(OD) + OD.sum(axis=0) - OD.sum(axis=1))
#     locs_len = len(N_k)                 # number of locations
#     SIR = np.zeros(shape=(locs_len, 3)) # make a numpy array with 3 columns for keeping track of the S, I, R groups
#     SIR[:,0] = N_k                      # initialize the S group with the respective populations
#     thresh1 = args.thresh1
#     thresh2 = args.thresh2
#
#     # BEN: This is the line I changed. It was returning an array of integers instead of floats.
#     # Cast it to float64 and the problem was fixed.
#     first_infections = np.where((thresh1 <= SIR[:, 0]) & (SIR[:, 0] <= thresh2), np.random.randint(1, args.infection_magnitude), 0).astype(np.float64)   # for demo purposes, randomly introduce infections
#     # NOTE: this is arbitrary but not actually random....
#     SIR[:, 0] = SIR[:, 0] - first_infections
#     SIR[:, 1] = SIR[:, 1] + first_infections                           # move infections to the I group
#
#     # row normalize the SIR matrix for keeping track of group proportions
#     row_sums = SIR.sum(axis=1)
#     SIR_n = SIR / row_sums[:, np.newaxis]
#
#     #initialize parameters
#     beta = args.beta
#     gamma = args.gamma
#     public_trans = args.public_trans                                 # alpha
#     R0 = beta/gamma
#     beta_vec = np.random.gamma(1.6, 2, locs_len)
#     gamma_vec = np.full(locs_len, gamma)
#     public_trans_vec = np.full(locs_len, public_trans)
#     fig_name = args.fig_name
#
#     # make copy of the SIR matrices
#     SIR_sim = SIR.copy()
#     SIR_nsim = SIR_n.copy()
#
#     # run model
#     #print(SIR_sim.sum(axis=0).sum() == N_k.sum())
#     days = 100
#     infected_pop_norm = np.zeros(days)
#     susceptible_pop_norm = np.zeros(days)
#     recovered_pop_norm = np.zeros(days)
#     for time_step in tqdm(range(days)):
#         infected_mat = np.array([SIR_nsim[:,1],]*locs_len).transpose()
#         OD_infected = np.round(OD*infected_mat)
#         inflow_infected = OD_infected.sum(axis=0)
#         inflow_infected = np.round(inflow_infected*public_trans_vec)
#         #print('total infected inflow: ', inflow_infected.sum())
#         new_infect = beta_vec*SIR_sim[:, 0]*inflow_infected/(N_k + OD.sum(axis=0))
#         new_recovered = gamma_vec*SIR_sim[:, 1]
#         new_infect = np.where(new_infect>SIR_sim[:, 0], SIR_sim[:, 0], new_infect)
#         SIR_sim[:, 0] = SIR_sim[:, 0] - new_infect
#         SIR_sim[:, 1] = SIR_sim[:, 1] + new_infect - new_recovered
#         SIR_sim[:, 2] = SIR_sim[:, 2] + new_recovered
#         SIR_sim = np.where(SIR_sim<0,0,SIR_sim)
#         # recompute the normalized SIR matrix
#         row_sums = SIR_sim.sum(axis=1)
#         SIR_nsim = SIR_sim / row_sums[:, np.newaxis]
#         S = SIR_sim[:,0].sum()/N_k.sum()
#         I = SIR_sim[:,1].sum()/N_k.sum()
#         R = SIR_sim[:,2].sum()/N_k.sum()
#         #print(S, I, R, (S+I+R)*N_k.sum(), N_k.sum())
#         #print('\n')
#         infected_pop_norm[time_step] = I
#         susceptible_pop_norm[time_step] = S
#         recovered_pop_norm[time_step] = R
#
#     graphing_function(infected_pop_norm, susceptible_pop_norm, recovered_pop_norm, days, fig_name)

# %%
print(args1.fig_name)
# Out:
# test

# %%
# %lprun -f covid_sim covid_sim(args1)
# Out:
# 100%|██████████| 100/100 [00:04<00:00, 23.82it/s]
# Fig name test

# %%
# %lprun -f multiprocess multiprocess(args2)
# Out:
# 100%|██████████| 100/100 [00:08<00:00, 12.20it/s]
# Fig name public_trans_0.4_(22, 555)_inf_10
# 100%|██████████| 100/100 [00:08<00:00, 12.26it/s]
# Fig name public_trans_0.4_(262, 332)_inf_9
# Fig name public_trans_0.1_(216, 352)_inf_9
# Fig name public_trans_0.2_(262, 630)_inf_11
