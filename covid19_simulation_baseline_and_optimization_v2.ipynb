# %% [markdown]
# ### Overview of the SIR model
#
# #### Add comments
#
# #### Add diagrams
#
# #### Add assertion for csv - columns, datatypes?

# %%
# We create feather file format to investigate if it speeds up data loading
import numpy as np
import pandas as pd
import feather
path = 'data/nyc_od.csv'
OD = pd.read_csv(path, header=None, dtype=np.float64)
path = 'data/nyc_od.feather'
feather.write_dataframe(OD, path)

# %% [markdown]
# ## Baseline Code

# %%
# %load_ext line_profiler

# %%
import numpy as np
from tqdm import tqdm
import argparse
from multiprocessing import cpu_count
from functools import partial
from multiprocessing.pool import Pool
import pandas as pd

# Matplotlib doesn't play nicely with multiprocessing, so
# we have to create a separate graphing function & import matplotlib inside of that.
def graphing_function(args, days, norms):
    import matplotlib.pyplot as plt
    susceptible_pop_norm, infected_pop_norm, recovered_pop_norm = norms
    public_trans_vec = np.asarray([float(i.replace('[', '').replace(',','').replace(']','')) for i in args.public_trans_vec])
    # plot results and save the plot
    fig = plt.figure()
    ax = plt.axes()
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.plot(np.arange(days), susceptible_pop_norm, label='Susceptible', color='#4aa5f0', linewidth=2)
    ax.plot(np.arange(days), infected_pop_norm, label='Infected', color='#f03737', linewidth=2)
    ax.plot(np.arange(days), recovered_pop_norm, label='Recovered', color='#82e88a', linewidth=2)
    ax.plot(np.arange(days), public_trans_vec, '--', label='Transit', color='k', linewidth=2)
    ax.legend(frameon=False)
    ax.set_xlabel("Days")
    ax.set_ylabel("Share of Population")
    if 'fig_name' in args:
        ax.figure.savefig('figures/' + args.fig_name + '.png')
    else:
        ax.figure.savefig('figures/sir_plot.png')
    plt.close()
    
# Convenience function: access Python dict keys as dict.key instead of dict['key']
class objdict(dict):
    def __getattr__(self, name):
        if name in self:
            return self[name]
        else:
            raise AttributeError("No such attribute: " + name)

    def __setattr__(self, name, value):
        self[name] = value

    def __delattr__(self, name):
        if name in self:
            del self[name]
        else:
            raise AttributeError("No such attribute: " + name)
            
# Run n simulations in parallel: for each run, parameters are randomly sampled from an interval
# NOTE: Are these intervals reasonable?
def multiprocess(args):

    chunks = []
    num_procs = args.randomize
    for _ in range(num_procs):
        d = dict()
        d['origin_matrix_path'] = args.origin_matrix_path
        d['thresh1'] = np.random.randint(0, 350)
        d['thresh2'] = np.random.randint(d['thresh1'], 700)
        d['infection_magnitude'] = np.random.randint(5, 15)
        d['beta'] = args.beta
        d['gamma'] = args.gamma
        d['public_trans'] = np.random.randint(1, 7) * 0.1
        d['public_trans_vec'] = np.asarray([i.replace('[', '').replace(',','').replace(']','') for i in args.public_trans_vec if i!=']'])
        d['days'] = args.days
        d['fig_name'] = 'public_trans_{:0.1f}_({}, {})_inf_{}'.format(d['public_trans'], d['thresh1'], d['thresh2'], d['infection_magnitude'])
        d['loading'] = args.loading
        d = objdict(d)
        chunks.append(d)

    with Pool(num_procs) as p:
        p.map(covid_sim, chunks)

    p.join()

def covid_sim(args):
    # Read in origin-destination flow matrix
    if int(args.loading) == 0:
        OD = np.genfromtxt(args.origin_matrix_path, delimiter=',')
        
    elif int(args.loading) == 1:
        OD = pd.read_csv('data/nyc_od.csv', header=None, dtype=np.float64).to_numpy()
        
    elif int(args.loading) == 2:
        OD = feather.read_dataframe('data/nyc_od.feather').to_numpy()
    

    # initialize the population vector from the origin-destination flow matrix
    N_k = np.abs(np.diagonal(OD) + OD.sum(axis=0) - OD.sum(axis=1))
    locs_len = len(N_k)                 # number of locations
    SIR = np.zeros(shape=(locs_len, 3)) # make a numpy array with 3 columns for keeping track of the S, I, R groups
    SIR[:,0] = N_k                      # initialize the S group with the respective populations
    thresh1 = args.thresh1
    thresh2 = args.thresh2

    first_infections = np.where((thresh1 <= SIR[:, 0]) & (SIR[:, 0] <= thresh2), np.random.randint(1, args.infection_magnitude), 0)   # for demo purposes, randomly introduce infections
    # NOTE: this is arbitrary but not actually random.... 
    SIR[:, 0] = SIR[:, 0] - first_infections
    SIR[:, 1] = SIR[:, 1] + first_infections                           # move infections to the I group

    # row normalize the SIR matrix for keeping track of group proportions
    row_sums = SIR.sum(axis=1)
    SIR_n = SIR / row_sums[:, np.newaxis]

    # initialize parameters
    beta = args.beta
    gamma = args.gamma
    public_trans = args.public_trans                                 # alpha
    R0 = beta/gamma
    beta_vec = np.random.gamma(beta, 2, locs_len)
    gamma_vec = np.full(locs_len, gamma)
    public_trans_vec = args.public_trans_vec
    if isinstance(public_trans_vec[0], str):
        public_trans_vec = np.asarray([float(i.replace('[', '').replace(',','').replace(']','')) for i in args.public_trans_vec if i!=']'])

    # make copy of the SIR matrices 
    SIR_sim = SIR.copy()
    SIR_nsim = SIR_n.copy()

    # run model
    #print(SIR_sim.sum(axis=0).sum() == N_k.sum())
    infected_pop_norm = []
    susceptible_pop_norm = []
    recovered_pop_norm = []
    days = args.days
    for time_step in tqdm(range(days)):
        infected_mat = np.array([SIR_nsim[:,1],]*locs_len).transpose()
        OD_infected = np.round(OD*infected_mat)
        inflow_infected = OD_infected.sum(axis=0)
        inflow_infected = np.round(inflow_infected*public_trans_vec[time_step])
        #print('total infected inflow: ', inflow_infected.sum())
        new_infect = beta_vec*SIR_sim[:, 0]*inflow_infected/(N_k + OD.sum(axis=0))
        new_recovered = gamma_vec*SIR_sim[:, 1]
        new_infect = np.where(new_infect>SIR_sim[:, 0], SIR_sim[:, 0], new_infect)
        SIR_sim[:, 0] = SIR_sim[:, 0] - new_infect
        SIR_sim[:, 1] = SIR_sim[:, 1] + new_infect - new_recovered
        SIR_sim[:, 2] = SIR_sim[:, 2] + new_recovered
        SIR_sim = np.where(SIR_sim<0,0,SIR_sim)
        # recompute the normalized SIR matrix
        row_sums = SIR_sim.sum(axis=1)
        SIR_nsim = SIR_sim / row_sums[:, np.newaxis]
        S = SIR_sim[:,0].sum()/N_k.sum()
        I = SIR_sim[:,1].sum()/N_k.sum()
        R = SIR_sim[:,2].sum()/N_k.sum()
        #print(S, I, R, (S+I+R)*N_k.sum(), N_k.sum())
        #print('\n')
        infected_pop_norm.append(I)
        susceptible_pop_norm.append(S)
        recovered_pop_norm.append(R)

    graphing_function(args, days, (susceptible_pop_norm, infected_pop_norm, recovered_pop_norm))

def covid_sim_serial(args):
    for i in range(args.randomize):
        covid_sim(args)

# %%
parser = argparse.ArgumentParser(description='COVID Simulator')
parser.add_argument('--randomize', type=int, default=0)
parser.add_argument('--origin-matrix-path', default='data/nyc_od.csv')
parser.add_argument('--thresh1', type=int, default=0)
parser.add_argument('--thresh2', type=int, default=100)
parser.add_argument('--infection-magnitude', type=int, default=10)
parser.add_argument('--beta', type=float, default=0.75)
parser.add_argument('--gamma', type=float, default=0.2)
parser.add_argument('--public-trans', type=float, default=0.5)
parser.add_argument('--public-trans-vec', nargs='+', default=[])
parser.add_argument('--days', type=int, default=100)
parser.add_argument('--img-folder', default='figures/')
parser.add_argument('--loading', default = 0)
parser.add_argument('--fig_name', default = 'sir_plot')
# Out:
# _StoreAction(option_strings=['--fig_name'], dest='fig_name', nargs=None, const=None, default='sir_plot', type=None, choices=None, help=None, metavar=None)

# %%
ptv = np.full(100, 0.56)

# %%
args1 = parser.parse_args(f'--randomize 4 --gamma 0.2 --days 100 --loading 0 --public-trans-vec {ptv}'.split())

# %% [markdown]
# ### Line Profiler Analysis
#
# Using lprun, we see that most of the time is spent loading in the Origin-Destination flow matrix (accounts for 39.2% of the time) and computing the element-wise matrix multiplication OD\*infected_mat and rounding it (accounts for 43.8% of the time). Note that the matrix multiplication occurs in a for-loop that runs multiple times while the loading of the matrix occurs only once. The percentage of time needed to perform all of the matrix multiplications at all of the time steps is roughly the same as the time needed to load in the matrix. We will first focus on trying read the OD matrix faster.

# %%
# %lprun -f covid_sim covid_sim(args1)
# Out:
# 100%|██████████| 100/100 [00:06<00:00, 16.65it/s]

# %% [raw]
# Timer unit: 1e-06 s
#
# Total time: 12.5601 s
# File: <ipython-input-3-024073cbdf1e>
# Function: covid_sim at line 78
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     78                                           def covid_sim(args):
#     79                                               # Read in origin-destination flow matrix
#     80         1          8.0      8.0      0.0      if int(args.loading) == 0:
#     81         1    5637177.0 5637177.0     44.9          OD = np.genfromtxt(args.origin_matrix_path, delimiter=',')
#     82
#     83                                               elif int(args.loading) == 1:
#     84                                                   OD = pd.read_csv('data/nyc_od.csv', header=None, dtype=np.float64).to_numpy()
#     85
#     86                                               elif int(args.loading) == 2:
#     87                                                   OD = feather.read_dataframe('data/nyc_od.feather').to_numpy()
#     88
#     89
#     90                                               # initialize the population vector from the origin-destination flow matrix
#     91         1      13353.0  13353.0      0.1      N_k = np.abs(np.diagonal(OD) + OD.sum(axis=0) - OD.sum(axis=1))
#     92         1          4.0      4.0      0.0      locs_len = len(N_k)                 # number of locations
#     93         1         35.0     35.0      0.0      SIR = np.zeros(shape=(locs_len, 3)) # make a numpy array with 3 columns for keeping track of the S, I, R groups
#     94         1          8.0      8.0      0.0      SIR[:,0] = N_k                      # initialize the S group with the respective populations
#     95         1          3.0      3.0      0.0      thresh1 = args.thresh1
#     96         1          1.0      1.0      0.0      thresh2 = args.thresh2
#     97
#     98         1       2445.0   2445.0      0.0      first_infections = np.where((thresh1 <= SIR[:, 0]) & (SIR[:, 0] <= thresh2), np.random.randint(1, args.infection_magnitude), 0)   # for demo purposes, randomly introduce infections
#     99                                               # NOTE: this is arbitrary but not actually random....
#    100         1         33.0     33.0      0.0      SIR[:, 0] = SIR[:, 0] - first_infections
#    101         1         12.0     12.0      0.0      SIR[:, 1] = SIR[:, 1] + first_infections                           # move infections to the I group
#    102
#    103                                               # row normalize the SIR matrix for keeping track of group proportions
#    104         1         74.0     74.0      0.0      row_sums = SIR.sum(axis=1)
#    105         1       1025.0   1025.0      0.0      SIR_n = SIR / row_sums[:, np.newaxis]
#    106
#    107                                               # initialize parameters
#    108         1          2.0      2.0      0.0      beta = args.beta
#    109         1          3.0      3.0      0.0      gamma = args.gamma
#    110         1          1.0      1.0      0.0      public_trans = args.public_trans                                 # alpha
#    111         1          2.0      2.0      0.0      R0 = beta/gamma
#    112         1       1263.0   1263.0      0.0      beta_vec = np.random.gamma(beta, 2, locs_len)
#    113         1         23.0     23.0      0.0      gamma_vec = np.full(locs_len, gamma)
#    114         1          2.0      2.0      0.0      public_trans_vec = args.public_trans_vec
#    115         1          4.0      4.0      0.0      if isinstance(public_trans_vec[0], str):
#    116         1        112.0    112.0      0.0          public_trans_vec = np.asarray([float(i.replace('[', '').replace(',','').replace(']','')) for i in args.public_trans_vec if i!=']'])
#    117
#    118                                               # make copy of the SIR matrices
#    119         1         11.0     11.0      0.0      SIR_sim = SIR.copy()
#    120         1         83.0     83.0      0.0      SIR_nsim = SIR_n.copy()
#    121
#    122                                               # run model
#    123                                               #print(SIR_sim.sum(axis=0).sum() == N_k.sum())
#    124         1          1.0      1.0      0.0      infected_pop_norm = []
#    125         1          1.0      1.0      0.0      susceptible_pop_norm = []
#    126         1          1.0      1.0      0.0      recovered_pop_norm = []
#    127         1          2.0      2.0      0.0      days = args.days
#    128       101      47607.0    471.4      0.4      for time_step in tqdm(range(days)):
#    129       100     914859.0   9148.6      7.3          infected_mat = np.array([SIR_nsim[:,1],]*locs_len).transpose()
#    130       100    4262874.0  42628.7     33.9          OD_infected = np.round(OD*infected_mat)
#    131       100     370795.0   3707.9      3.0          inflow_infected = OD_infected.sum(axis=0)
#    132       100       4146.0     41.5      0.0          inflow_infected = np.round(inflow_infected*public_trans_vec[time_step])
#    133                                                   #print('total infected inflow: ', inflow_infected.sum())
#    134       100     392248.0   3922.5      3.1          new_infect = beta_vec*SIR_sim[:, 0]*inflow_infected/(N_k + OD.sum(axis=0))
#    135       100       1260.0     12.6      0.0          new_recovered = gamma_vec*SIR_sim[:, 1]
#    136       100       1477.0     14.8      0.0          new_infect = np.where(new_infect>SIR_sim[:, 0], SIR_sim[:, 0], new_infect)
#    137       100        971.0      9.7      0.0          SIR_sim[:, 0] = SIR_sim[:, 0] - new_infect
#    138       100        932.0      9.3      0.0          SIR_sim[:, 1] = SIR_sim[:, 1] + new_infect - new_recovered
#    139       100        627.0      6.3      0.0          SIR_sim[:, 2] = SIR_sim[:, 2] + new_recovered
#    140       100       2211.0     22.1      0.0          SIR_sim = np.where(SIR_sim<0,0,SIR_sim)
#    141                                                   # recompute the normalized SIR matrix
#    142       100       4790.0     47.9      0.0          row_sums = SIR_sim.sum(axis=1)
#    143       100       2517.0     25.2      0.0          SIR_nsim = SIR_sim / row_sums[:, np.newaxis]
#    144       100       1540.0     15.4      0.0          S = SIR_sim[:,0].sum()/N_k.sum()
#    145       100        919.0      9.2      0.0          I = SIR_sim[:,1].sum()/N_k.sum()
#    146       100        848.0      8.5      0.0          R = SIR_sim[:,2].sum()/N_k.sum()
#    147                                                   #print(S, I, R, (S+I+R)*N_k.sum(), N_k.sum())
#    148                                                   #print('\n')
#    149       100        183.0      1.8      0.0          infected_pop_norm.append(I)
#    150       100         91.0      0.9      0.0          susceptible_pop_norm.append(S)
#    151       100        116.0      1.2      0.0          recovered_pop_norm.append(R)
#    152
#    153         1     893376.0 893376.0      7.1      graphing_function(args, days, (susceptible_pop_norm, infected_pop_norm, recovered_pop_norm))

# %%
# %lprun -f covid_sim_serial covid_sim_serial(args1)
# Out:
# 100%|██████████| 100/100 [00:06<00:00, 14.33it/s]
# 100%|██████████| 100/100 [00:06<00:00, 12.60it/s]
# 100%|██████████| 100/100 [00:06<00:00, 15.51it/s]
# 100%|██████████| 100/100 [00:05<00:00, 17.54it/s]

# %% [raw]
# Timer unit: 1e-06 s
#
# Total time: 50.7105 s
# File: <ipython-input-3-024073cbdf1e>
# Function: covid_sim_serial at line 155
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    155                                           def covid_sim_serial(args):
#    156         5         15.0      3.0      0.0      for i in range(args.randomize):
#    157         4   50710500.0 12677625.0    100.0          covid_sim(args)

# %%
# %lprun -f multiprocess multiprocess(args1)
# Out:
# 100%|██████████| 100/100 [00:14<00:00,  7.14it/s]
# 100%|██████████| 100/100 [00:14<00:00,  7.09it/s]
# 100%|██████████| 100/100 [00:15<00:00,  7.32it/s]
# 100%|██████████| 100/100 [00:15<00:00,  7.41it/s]

# %% [raw]
# Timer unit: 1e-06 s
#
# Total time: 31.5627 s
# File: <ipython-input-3-024073cbdf1e>
# Function: multiprocess at line 53
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     53                                           def multiprocess(args):
#     54
#     55         1          4.0      4.0      0.0      chunks = []
#     56         1          2.0      2.0      0.0      num_procs = args.randomize
#     57         5          6.0      1.2      0.0      for _ in range(num_procs):
#     58         4          6.0      1.5      0.0          d = dict()
#     59         4          5.0      1.2      0.0          d['origin_matrix_path'] = args.origin_matrix_path
#     60         4         96.0     24.0      0.0          d['thresh1'] = np.random.randint(0, 350)
#     61         4         21.0      5.2      0.0          d['thresh2'] = np.random.randint(d['thresh1'], 700)
#     62         4         16.0      4.0      0.0          d['infection_magnitude'] = np.random.randint(5, 15)
#     63         4          6.0      1.5      0.0          d['beta'] = args.beta
#     64         4          6.0      1.5      0.0          d['gamma'] = args.gamma
#     65         4         18.0      4.5      0.0          d['public_trans'] = np.random.randint(1, 7) * 0.1
#     66         4        915.0    228.8      0.0          d['public_trans_vec'] = np.asarray([i.replace('[', '').replace(',','').replace(']','') for i in args.public_trans_vec if i!=']'])
#     67         4          9.0      2.2      0.0          d['days'] = args.days
#     68         4         26.0      6.5      0.0          d['fig_name'] = 'public_trans_{:0.1f}_({}, {})_inf_{}'.format(d['public_trans'], d['thresh1'], d['thresh2'], d['infection_magnitude'])
#     69         4          8.0      2.0      0.0          d['loading'] = args.loading
#     70         4         12.0      3.0      0.0          d = objdict(d)
#     71         4          5.0      1.2      0.0          chunks.append(d)
#     72
#     73         1      22875.0  22875.0      0.1      with Pool(num_procs) as p:
#     74         1   31538577.0 31538577.0     99.9          p.map(covid_sim, chunks)
#     75
#     76         1         40.0     40.0      0.0      p.join()

# %% [markdown]
# We try data loading using pandas, given by loading argument value of 1 and feather, given by loading argument value of 2.

# %%
args2 = parser.parse_args(f'--randomize 4 --gamma 0.2 --days 100 --public-trans-vec {ptv} --loading 1'.split())

# %%
args3 = parser.parse_args(f'--randomize 4 --gamma 0.2 --days 100 --public-trans-vec {ptv} --loading 2'.split())

# %%
# %lprun -f covid_sim_serial covid_sim_serial(args2)
# Out:
# 100%|██████████| 100/100 [00:03<00:00, 32.42it/s]
# 100%|██████████| 100/100 [00:02<00:00, 34.63it/s]
# 100%|██████████| 100/100 [00:02<00:00, 35.40it/s]
# 100%|██████████| 100/100 [00:02<00:00, 34.59it/s]

# %% [raw]
# Timer unit: 1e-06 s
#
# Total time: 15.661 s
# File: <ipython-input-29-024073cbdf1e>
# Function: covid_sim_serial at line 155
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    155                                           def covid_sim_serial(args):
#    156         5         14.0      2.8      0.0      for i in range(args.randomize):
#    157         4   15661004.0 3915251.0    100.0          covid_sim(args)

# %%
# %lprun -f multiprocess multiprocess(args2)
# Out:
# 100%|██████████| 100/100 [00:08<00:00, 11.47it/s]
# 100%|██████████| 100/100 [00:08<00:00, 11.41it/s]
# 100%|██████████| 100/100 [00:08<00:00, 11.06it/s]
# 100%|██████████| 100/100 [00:08<00:00, 11.54it/s]

# %% [raw]
# Timer unit: 1e-06 s
#
# Total time: 10.8917 s
# File: <ipython-input-29-024073cbdf1e>
# Function: multiprocess at line 53
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     53                                           def multiprocess(args):
#     54
#     55         1          2.0      2.0      0.0      chunks = []
#     56         1          2.0      2.0      0.0      num_procs = args.randomize
#     57         5          5.0      1.0      0.0      for _ in range(num_procs):
#     58         4          4.0      1.0      0.0          d = dict()
#     59         4          4.0      1.0      0.0          d['origin_matrix_path'] = args.origin_matrix_path
#     60         4         31.0      7.8      0.0          d['thresh1'] = np.random.randint(0, 350)
#     61         4         13.0      3.2      0.0          d['thresh2'] = np.random.randint(d['thresh1'], 700)
#     62         4          8.0      2.0      0.0          d['infection_magnitude'] = np.random.randint(5, 15)
#     63         4          4.0      1.0      0.0          d['beta'] = args.beta
#     64         4          5.0      1.2      0.0          d['gamma'] = args.gamma
#     65         4         11.0      2.8      0.0          d['public_trans'] = np.random.randint(1, 7) * 0.1
#     66         4        316.0     79.0      0.0          d['public_trans_vec'] = np.asarray([i.replace('[', '').replace(',','').replace(']','') for i in args.public_trans_vec if i!=']'])
#     67         4          8.0      2.0      0.0          d['days'] = args.days
#     68         4         13.0      3.2      0.0          d['fig_name'] = 'public_trans_{:0.1f}_({}, {})_inf_{}'.format(d['public_trans'], d['thresh1'], d['thresh2'], d['infection_magnitude'])
#     69         4          4.0      1.0      0.0          d['loading'] = args.loading
#     70         4          8.0      2.0      0.0          d = objdict(d)
#     71         4          3.0      0.8      0.0          chunks.append(d)
#     72
#     73         1      30603.0  30603.0      0.3      with Pool(num_procs) as p:
#     74         1   10860570.0 10860570.0     99.7          p.map(covid_sim, chunks)
#     75
#     76         1         67.0     67.0      0.0      p.join()

# %%
# %lprun -f covid_sim_serial covid_sim_serial(args3)
# Out:
# 100%|██████████| 100/100 [00:03<00:00, 34.80it/s]
# 100%|██████████| 100/100 [00:02<00:00, 34.17it/s]
# 100%|██████████| 100/100 [00:03<00:00, 25.05it/s]
# 100%|██████████| 100/100 [00:02<00:00, 37.39it/s]

# %% [raw]
# Timer unit: 1e-06 s
#
# Total time: 13.6371 s
# File: <ipython-input-3-024073cbdf1e>
# Function: covid_sim_serial at line 155
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    155                                           def covid_sim_serial(args):
#    156         5         15.0      3.0      0.0      for i in range(args.randomize):
#    157         4   13637090.0 3409272.5    100.0          covid_sim(args)

# %%
# %lprun -f multiprocess multiprocess(args3)
# Out:
# 100%|██████████| 100/100 [00:09<00:00, 10.92it/s]
# 100%|██████████| 100/100 [00:09<00:00, 10.76it/s]
#
# 100%|██████████| 100/100 [00:09<00:00, 10.56it/s]

# %% [raw]
# Timer unit: 1e-06 s
#
# Total time: 10.0052 s
# File: <ipython-input-3-024073cbdf1e>
# Function: multiprocess at line 53
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     53                                           def multiprocess(args):
#     54
#     55         1          2.0      2.0      0.0      chunks = []
#     56         1          3.0      3.0      0.0      num_procs = args.randomize
#     57         5          6.0      1.2      0.0      for _ in range(num_procs):
#     58         4          4.0      1.0      0.0          d = dict()
#     59         4          4.0      1.0      0.0          d['origin_matrix_path'] = args.origin_matrix_path
#     60         4         73.0     18.2      0.0          d['thresh1'] = np.random.randint(0, 350)
#     61         4         19.0      4.8      0.0          d['thresh2'] = np.random.randint(d['thresh1'], 700)
#     62         4         64.0     16.0      0.0          d['infection_magnitude'] = np.random.randint(5, 15)
#     63         4          5.0      1.2      0.0          d['beta'] = args.beta
#     64         4          6.0      1.5      0.0          d['gamma'] = args.gamma
#     65         4         20.0      5.0      0.0          d['public_trans'] = np.random.randint(1, 7) * 0.1
#     66         4       1008.0    252.0      0.0          d['public_trans_vec'] = np.asarray([i.replace('[', '').replace(',','').replace(']','') for i in args.public_trans_vec if i!=']'])
#     67         4          8.0      2.0      0.0          d['days'] = args.days
#     68         4         24.0      6.0      0.0          d['fig_name'] = 'public_trans_{:0.1f}_({}, {})_inf_{}'.format(d['public_trans'], d['thresh1'], d['thresh2'], d['infection_magnitude'])
#     69         4          9.0      2.2      0.0          d['loading'] = args.loading
#     70         4         13.0      3.2      0.0          d = objdict(d)
#     71         4          8.0      2.0      0.0          chunks.append(d)
#     72
#     73         1      17080.0  17080.0      0.2      with Pool(num_procs) as p:
#     74         1    9986812.0 9986812.0     99.8          p.map(covid_sim, chunks)
#     75
#     76         1         39.0     39.0      0.0      p.join()

# %% [markdown]
# We find that loading data with feather works the fastest, so we'll be using that going forward.

# %% [markdown]
# ### Improving Matrix Multiplication using Cython
#
# We want to investigate if using Cython can provide a greater speedup.

# %%
# %load_ext Cython

# %%
# %%cython
#
# # cython: profile=True
# # cython: linetrace=True
# # cython: binding=True
# # distutils: define_macros=CYTHON_TRACE_NOGIL=1
#
# import numpy as np
# from tqdm import tqdm
# import argparse
# from multiprocessing import cpu_count
# from functools import partial
# from multiprocessing.pool import Pool
# import pandas as pd
# import feather
#
# # Matplotlib doesn't play nicely with multiprocessing, so
# # we have to create a separate graphing function & import matplotlib inside of that.
# def graphing_function(args, days, norms):
#     import matplotlib.pyplot as plt
#     susceptible_pop_norm, infected_pop_norm, recovered_pop_norm = norms
#     public_trans_vec = np.asarray([float(i.replace('[', '').replace(',','').replace(']','')) for i in args.public_trans_vec])
#     # plot results and save the plot
#     fig = plt.figure()
#     ax = plt.axes()
#     ax.spines['right'].set_visible(False)
#     ax.spines['top'].set_visible(False)
#     ax.spines['left'].set_visible(False)
#     ax.plot(np.arange(days), susceptible_pop_norm, label='Susceptible', color='#4aa5f0', linewidth=2)
#     ax.plot(np.arange(days), infected_pop_norm, label='Infected', color='#f03737', linewidth=2)
#     ax.plot(np.arange(days), recovered_pop_norm, label='Recovered', color='#82e88a', linewidth=2)
#     ax.plot(np.arange(days), public_trans_vec, '--', label='Transit', color='k', linewidth=2)
#     ax.legend(frameon=False)
#     ax.set_xlabel("Days")
#     ax.set_ylabel("Share of Population")
#     if 'fig_name' in args:
#         ax.figure.savefig('figures/' + args.fig_name + '.png')
#     else:
#         ax.figure.savefig('figures/sir_plot.png')
#     plt.close()
#
# # Convenience function: access Python dict keys as dict.key instead of dict['key']
# class objdict(dict):
#     def __getattr__(self, name):
#         if name in self:
#             return self[name]
#         else:
#             raise AttributeError("No such attribute: " + name)
#
#     def __setattr__(self, name, value):
#         self[name] = value
#
#     def __delattr__(self, name):
#         if name in self:
#             del self[name]
#         else:
#             raise AttributeError("No such attribute: " + name)
#
# # Run n simulations in parallel: for each run, parameters are randomly sampled from an interval
# # NOTE: Are these intervals reasonable?
# def multiprocess(args):
#
#     chunks = []
#     num_procs = args.randomize
#     for _ in range(num_procs):
#         d = dict()
#         d['origin_matrix_path'] = args.origin_matrix_path
#         d['thresh1'] = np.random.randint(0, 350)
#         d['thresh2'] = np.random.randint(d['thresh1'], 700)
#         d['infection_magnitude'] = np.random.randint(5, 15)
#         d['beta'] = args.beta
#         d['gamma'] = args.gamma
#         d['public_trans'] = np.random.randint(1, 7) * 0.1
#         d['public_trans_vec'] = np.asarray([i.replace('[', '').replace(',','').replace(']','') for i in args.public_trans_vec if i!=']'])
#         d['days'] = args.days
#         d['fig_name'] = 'public_trans_{:0.1f}_({}, {})_inf_{}'.format(d['public_trans'], d['thresh1'], d['thresh2'], d['infection_magnitude'])
#         d['loading'] = args.loading
#         d = objdict(d)
#         chunks.append(d)
#
#     with Pool(num_procs) as p:
#         p.map(covid_sim, chunks)
#
#     p.join()
#
# def covid_sim(args):
#     # Read in origin-destination flow matrix
#     if int(args.loading) == 0:
#         OD = np.genfromtxt(args.origin_matrix_path, delimiter=',')
#
#     elif int(args.loading) == 1:
#         OD = pd.read_csv('data/nyc_od.csv', header=None, dtype=np.float64).to_numpy()
#
#     elif int(args.loading) == 2:
#         OD = feather.read_dataframe('data/nyc_od.feather').to_numpy()
#
#
#     # initialize the population vector from the origin-destination flow matrix
#     N_k = np.abs(np.diagonal(OD) + OD.sum(axis=0) - OD.sum(axis=1))
#     locs_len = len(N_k)                 # number of locations
#     SIR = np.zeros(shape=(locs_len, 3)) # make a numpy array with 3 columns for keeping track of the S, I, R groups
#     SIR[:,0] = N_k                      # initialize the S group with the respective populations
#     thresh1 = args.thresh1
#     thresh2 = args.thresh2
#
#     first_infections = np.where((thresh1 <= SIR[:, 0]) & (SIR[:, 0] <= thresh2), np.random.randint(1, args.infection_magnitude), 0)   # for demo purposes, randomly introduce infections
#     # NOTE: this is arbitrary but not actually random....
#     SIR[:, 0] = SIR[:, 0] - first_infections
#     SIR[:, 1] = SIR[:, 1] + first_infections                           # move infections to the I group
#
#     # row normalize the SIR matrix for keeping track of group proportions
#     row_sums = SIR.sum(axis=1)
#     SIR_n = SIR / row_sums[:, np.newaxis]
#
#     # initialize parameters
#     beta = args.beta
#     gamma = args.gamma
#     public_trans = args.public_trans                                 # alpha
#     R0 = beta/gamma
#     beta_vec = np.random.gamma(beta, 2, locs_len)
#     gamma_vec = np.full(locs_len, gamma)
#     public_trans_vec = args.public_trans_vec
#     if isinstance(public_trans_vec[0], str):
#         public_trans_vec = np.asarray([float(i.replace('[', '').replace(',','').replace(']','')) for i in args.public_trans_vec if i!=']'])
#
#     # make copy of the SIR matrices
#     SIR_sim = SIR.copy()
#     SIR_nsim = SIR_n.copy()
#
#     # run model
#     #print(SIR_sim.sum(axis=0).sum() == N_k.sum())
#     infected_pop_norm = []
#     susceptible_pop_norm = []
#     recovered_pop_norm = []
#     days = args.days
#     for time_step in tqdm(range(days)):
#         infected_mat = np.array([SIR_nsim[:,1],]*locs_len).transpose()
#         OD_infected = np.round(OD*infected_mat)
#         inflow_infected = OD_infected.sum(axis=0)
#         inflow_infected = np.round(inflow_infected*public_trans_vec[time_step])
#         #print('total infected inflow: ', inflow_infected.sum())
#         new_infect = beta_vec*SIR_sim[:, 0]*inflow_infected/(N_k + OD.sum(axis=0))
#         new_recovered = gamma_vec*SIR_sim[:, 1]
#         new_infect = np.where(new_infect>SIR_sim[:, 0], SIR_sim[:, 0], new_infect)
#         SIR_sim[:, 0] = SIR_sim[:, 0] - new_infect
#         SIR_sim[:, 1] = SIR_sim[:, 1] + new_infect - new_recovered
#         SIR_sim[:, 2] = SIR_sim[:, 2] + new_recovered
#         SIR_sim = np.where(SIR_sim<0,0,SIR_sim)
#         # recompute the normalized SIR matrix
#         row_sums = SIR_sim.sum(axis=1)
#         SIR_nsim = SIR_sim / row_sums[:, np.newaxis]
#         S = SIR_sim[:,0].sum()/N_k.sum()
#         I = SIR_sim[:,1].sum()/N_k.sum()
#         R = SIR_sim[:,2].sum()/N_k.sum()
#         #print(S, I, R, (S+I+R)*N_k.sum(), N_k.sum())
#         #print('\n')
#         infected_pop_norm.append(I)
#         susceptible_pop_norm.append(S)
#         recovered_pop_norm.append(R)
#
#     graphing_function(args, days, (susceptible_pop_norm, infected_pop_norm, recovered_pop_norm))
#
# def covid_sim_serial(args):
#     for i in range(args.randomize):
#         covid_sim(args)

# %%
# %lprun -f covid_sim_serial covid_sim_serial(args3)
# Out:
# 100%|██████████| 100/100 [00:02<00:00, 35.06it/s]
# 100%|██████████| 100/100 [00:03<00:00, 33.13it/s]
# 100%|██████████| 100/100 [00:02<00:00, 35.27it/s]
# 100%|██████████| 100/100 [00:02<00:00, 34.57it/s]

# %% [raw]
# Timer unit: 1e-06 s
#
# Total time: 12.4706 s
# File: /Users/sree/.ipython/cython/_cython_magic_d3c149e6fef5ce8efd1e3c7b13b021a1.pyx
# Function: covid_sim_serial at line 162
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    162                                           def covid_sim_serial(args):
#    163         5       1480.0    296.0      0.0      for i in range(args.randomize):
#    164         4   12469133.0 3117283.2    100.0          covid_sim(args)

# %%
# %lprun -f multiprocess multiprocess(args3)
# Out:
# 100%|██████████| 100/100 [00:09<00:00, 10.61it/s]
# 100%|██████████| 100/100 [00:09<00:00, 10.56it/s]
# 100%|██████████| 100/100 [00:09<00:00, 10.51it/s]
# 100%|██████████| 100/100 [00:09<00:00, 10.42it/s]

# %% [raw]
# Timer unit: 1e-06 s
#
# Total time: 10.126 s
# File: /Users/sree/.ipython/cython/_cython_magic_d3c149e6fef5ce8efd1e3c7b13b021a1.pyx
# Function: multiprocess at line 60
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     60                                           def multiprocess(args):
#     61
#     62         1          3.0      3.0      0.0      chunks = []
#     63         1          4.0      4.0      0.0      num_procs = args.randomize
#     64         5          9.0      1.8      0.0      for _ in range(num_procs):
#     65         4          2.0      0.5      0.0          d = dict()
#     66         4          2.0      0.5      0.0          d['origin_matrix_path'] = args.origin_matrix_path
#     67         4         41.0     10.2      0.0          d['thresh1'] = np.random.randint(0, 350)
#     68         4         11.0      2.8      0.0          d['thresh2'] = np.random.randint(d['thresh1'], 700)
#     69         4          8.0      2.0      0.0          d['infection_magnitude'] = np.random.randint(5, 15)
#     70         4          3.0      0.8      0.0          d['beta'] = args.beta
#     71         4          4.0      1.0      0.0          d['gamma'] = args.gamma
#     72         4         10.0      2.5      0.0          d['public_trans'] = np.random.randint(1, 7) * 0.1
#     73         4        239.0     59.8      0.0          d['public_trans_vec'] = np.asarray([i.replace('[', '').replace(',','').replace(']','') for i in args.public_trans_vec if i!=']'])
#     74         4          5.0      1.2      0.0          d['days'] = args.days
#     75         4         20.0      5.0      0.0          d['fig_name'] = 'public_trans_{:0.1f}_({}, {})_inf_{}'.format(d['public_trans'], d['thresh1'], d['thresh2'], d['infection_magnitude'])
#     76         4          4.0      1.0      0.0          d['loading'] = args.loading
#     77         4          7.0      1.8      0.0          d = objdict(d)
#     78         4          2.0      0.5      0.0          chunks.append(d)
#     79
#     80         1      31356.0  31356.0      0.3      with Pool(num_procs) as p:
#     81         1   10093034.0 10093034.0     99.7          p.map(covid_sim, chunks)
#     82
#     83         1       1213.0   1213.0      0.0      p.join()

# %% [markdown]
# We see a slight speed up when compiling with Cython without specifying the types of the variables for both serial and multiprocessing.

# %% [markdown]
# ### Cython + Removing tqdm
#
# We wanted to see if removing tqdm could provide an additional speedup.

# %%
# %%cython
#
# # cython: profile=True
# # cython: linetrace=True
# # cython: binding=True
# # distutils: define_macros=CYTHON_TRACE_NOGIL=1
#
# import numpy as np
# from tqdm import tqdm
# import argparse
# from multiprocessing import cpu_count
# from functools import partial
# from multiprocessing.pool import Pool
# import pandas as pd
# import feather
#
# # Matplotlib doesn't play nicely with multiprocessing, so
# # we have to create a separate graphing function & import matplotlib inside of that.
# def graphing_function(args, days, norms):
#     import matplotlib.pyplot as plt
#     susceptible_pop_norm, infected_pop_norm, recovered_pop_norm = norms
#     public_trans_vec = np.asarray([float(i.replace('[', '').replace(',','').replace(']','')) for i in args.public_trans_vec])
#     # plot results and save the plot
#     fig = plt.figure()
#     ax = plt.axes()
#     ax.spines['right'].set_visible(False)
#     ax.spines['top'].set_visible(False)
#     ax.spines['left'].set_visible(False)
#     ax.plot(np.arange(days), susceptible_pop_norm, label='Susceptible', color='#4aa5f0', linewidth=2)
#     ax.plot(np.arange(days), infected_pop_norm, label='Infected', color='#f03737', linewidth=2)
#     ax.plot(np.arange(days), recovered_pop_norm, label='Recovered', color='#82e88a', linewidth=2)
#     ax.plot(np.arange(days), public_trans_vec, '--', label='Transit', color='k', linewidth=2)
#     ax.legend(frameon=False)
#     ax.set_xlabel("Days")
#     ax.set_ylabel("Share of Population")
#     if 'fig_name' in args:
#         ax.figure.savefig('figures/' + args.fig_name + '.png')
#     else:
#         ax.figure.savefig('figures/sir_plot.png')
#     plt.close()
#
# # Convenience function: access Python dict keys as dict.key instead of dict['key']
# class objdict(dict):
#     def __getattr__(self, name):
#         if name in self:
#             return self[name]
#         else:
#             raise AttributeError("No such attribute: " + name)
#
#     def __setattr__(self, name, value):
#         self[name] = value
#
#     def __delattr__(self, name):
#         if name in self:
#             del self[name]
#         else:
#             raise AttributeError("No such attribute: " + name)
#
# # Run n simulations in parallel: for each run, parameters are randomly sampled from an interval
# # NOTE: Are these intervals reasonable?
# def multiprocess(args):
#
#     chunks = []
#     num_procs = args.randomize
#     for _ in range(num_procs):
#         d = dict()
#         d['origin_matrix_path'] = args.origin_matrix_path
#         d['thresh1'] = np.random.randint(0, 350)
#         d['thresh2'] = np.random.randint(d['thresh1'], 700)
#         d['infection_magnitude'] = np.random.randint(5, 15)
#         d['beta'] = args.beta
#         d['gamma'] = args.gamma
#         d['public_trans'] = np.random.randint(1, 7) * 0.1
#         d['public_trans_vec'] = np.asarray([i.replace('[', '').replace(',','').replace(']','') for i in args.public_trans_vec])
#         d['days'] = args.days
#         d['fig_name'] = 'public_trans_{:0.1f}_({}, {})_inf_{}'.format(d['public_trans'], d['thresh1'], d['thresh2'], d['infection_magnitude'])
#         d['loading'] = args.loading
#         d = objdict(d)
#         chunks.append(d)
#
#     with Pool(num_procs) as p:
#         p.map(covid_sim, chunks)
#
#     p.join()
#
# def covid_sim(args):
#     # Read in origin-destination flow matrix
#     if int(args.loading) == 0:
#         OD = np.genfromtxt(args.origin_matrix_path, delimiter=',')
#
#     elif int(args.loading) == 1:
#         OD = pd.read_csv('data/nyc_od.csv', header=None, dtype=np.float64).to_numpy()
#
#     elif int(args.loading) == 2:
#         OD = feather.read_dataframe('data/nyc_od.feather').to_numpy()
#
#
#     # initialize the population vector from the origin-destination flow matrix
#     N_k = np.abs(np.diagonal(OD) + OD.sum(axis=0) - OD.sum(axis=1))
#     locs_len = len(N_k)                 # number of locations
#     SIR = np.zeros(shape=(locs_len, 3)) # make a numpy array with 3 columns for keeping track of the S, I, R groups
#     SIR[:,0] = N_k                      # initialize the S group with the respective populations
#     thresh1 = args.thresh1
#     thresh2 = args.thresh2
#
#     first_infections = np.where((thresh1 <= SIR[:, 0]) & (SIR[:, 0] <= thresh2), np.random.randint(1, args.infection_magnitude), 0)   # for demo purposes, randomly introduce infections
#     # NOTE: this is arbitrary but not actually random....
#     SIR[:, 0] = SIR[:, 0] - first_infections
#     SIR[:, 1] = SIR[:, 1] + first_infections                           # move infections to the I group
#
#     # row normalize the SIR matrix for keeping track of group proportions
#     row_sums = SIR.sum(axis=1)
#     SIR_n = SIR / row_sums[:, np.newaxis]
#
#     # initialize parameters
#     beta = args.beta
#     gamma = args.gamma
#     public_trans = args.public_trans                                 # alpha
#     R0 = beta/gamma
#     beta_vec = np.random.gamma(beta, 2, locs_len)
#     gamma_vec = np.full(locs_len, gamma)
#     public_trans_vec = args.public_trans_vec
#     if isinstance(public_trans_vec[0], str):
#         public_trans_vec = np.asarray([float(i.replace('[', '').replace(',','').replace(']','')) for i in public_trans_vec if i != ']'])
#
#     # make copy of the SIR matrices
#     SIR_sim = SIR.copy()
#     SIR_nsim = SIR_n.copy()
#
#     # run model
#     #print(SIR_sim.sum(axis=0).sum() == N_k.sum())
#     infected_pop_norm = []
#     susceptible_pop_norm = []
#     recovered_pop_norm = []
#     days = args.days
#     for time_step in range(days):
#         infected_mat = np.array([SIR_nsim[:,1],]*locs_len).transpose()
#         OD_infected = np.round(OD*infected_mat)
#         inflow_infected = OD_infected.sum(axis=0)
#         inflow_infected = np.round(inflow_infected*public_trans_vec[time_step])
#         #print('total infected inflow: ', inflow_infected.sum())
#         new_infect = beta_vec*SIR_sim[:, 0]*inflow_infected/(N_k + OD.sum(axis=0))
#         new_recovered = gamma_vec*SIR_sim[:, 1]
#         new_infect = np.where(new_infect>SIR_sim[:, 0], SIR_sim[:, 0], new_infect)
#         SIR_sim[:, 0] = SIR_sim[:, 0] - new_infect
#         SIR_sim[:, 1] = SIR_sim[:, 1] + new_infect - new_recovered
#         SIR_sim[:, 2] = SIR_sim[:, 2] + new_recovered
#         SIR_sim = np.where(SIR_sim<0,0,SIR_sim)
#         # recompute the normalized SIR matrix
#         row_sums = SIR_sim.sum(axis=1)
#         SIR_nsim = SIR_sim / row_sums[:, np.newaxis]
#         S = SIR_sim[:,0].sum()/N_k.sum()
#         I = SIR_sim[:,1].sum()/N_k.sum()
#         R = SIR_sim[:,2].sum()/N_k.sum()
#         #print(S, I, R, (S+I+R)*N_k.sum(), N_k.sum())
#         #print('\n')
#         infected_pop_norm.append(I)
#         susceptible_pop_norm.append(S)
#         recovered_pop_norm.append(R)
#
#     graphing_function(args, days, (susceptible_pop_norm, infected_pop_norm, recovered_pop_norm))
#
# def covid_sim_serial(args):
#     for i in range(args.randomize):
#         covid_sim(args)

# %%
# fastest process - checking overall improvement for 1 run
# %lprun -f covid_sim covid_sim(args3)

# %% [raw]
# Timer unit: 1e-06 s
#
# Total time: 3.66279 s
# File: /Users/sree/.ipython/cython/_cython_magic_fc024b63ed9cd3c1a2712e2c40b2da82.pyx
# Function: covid_sim at line 85
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     85                                           def covid_sim(args):
#     86                                               # Read in origin-destination flow matrix
#     87         1          9.0      9.0      0.0      if int(args.loading) == 0:
#     88                                                   OD = np.genfromtxt(args.origin_matrix_path, delimiter=',')
#     89
#     90         1          7.0      7.0      0.0      elif int(args.loading) == 1:
#     91                                                   OD = pd.read_csv('data/nyc_od.csv', header=None, dtype=np.float64).to_numpy()
#     92
#     93         1          4.0      4.0      0.0      elif int(args.loading) == 2:
#     94         1     351918.0 351918.0      9.6          OD = feather.read_dataframe('data/nyc_od.feather').to_numpy()
#     95
#     96
#     97                                               # initialize the population vector from the origin-destination flow matrix
#     98         1       6324.0   6324.0      0.2      N_k = np.abs(np.diagonal(OD) + OD.sum(axis=0) - OD.sum(axis=1))
#     99         1          2.0      2.0      0.0      locs_len = len(N_k)                 # number of locations
#    100         1         17.0     17.0      0.0      SIR = np.zeros(shape=(locs_len, 3)) # make a numpy array with 3 columns for keeping track of the S, I, R groups
#    101         1          5.0      5.0      0.0      SIR[:,0] = N_k                      # initialize the S group with the respective populations
#    102         1          2.0      2.0      0.0      thresh1 = args.thresh1
#    103         1          0.0      0.0      0.0      thresh2 = args.thresh2
#    104
#    105         1         42.0     42.0      0.0      first_infections = np.where((thresh1 <= SIR[:, 0]) & (SIR[:, 0] <= thresh2), np.random.randint(1, args.infection_magnitude), 0)   # for demo purposes, randomly introduce infections
#    106                                               # NOTE: this is arbitrary but not actually random....
#    107         1         10.0     10.0      0.0      SIR[:, 0] = SIR[:, 0] - first_infections
#    108         1          8.0      8.0      0.0      SIR[:, 1] = SIR[:, 1] + first_infections                           # move infections to the I group
#    109
#    110                                               # row normalize the SIR matrix for keeping track of group proportions
#    111         1         45.0     45.0      0.0      row_sums = SIR.sum(axis=1)
#    112         1         30.0     30.0      0.0      SIR_n = SIR / row_sums[:, np.newaxis]
#    113
#    114                                               # initialize parameters
#    115         1          1.0      1.0      0.0      beta = args.beta
#    116         1          0.0      0.0      0.0      gamma = args.gamma
#    117         1          0.0      0.0      0.0      public_trans = args.public_trans                                 # alpha
#    118         1          1.0      1.0      0.0      R0 = beta/gamma
#    119         1        194.0    194.0      0.0      beta_vec = np.random.gamma(beta, 2, locs_len)
#    120         1         13.0     13.0      0.0      gamma_vec = np.full(locs_len, gamma)
#    121         1          1.0      1.0      0.0      public_trans_vec = args.public_trans_vec
#    122         1          1.0      1.0      0.0      if isinstance(public_trans_vec[0], str):
#    123         1         50.0     50.0      0.0          public_trans_vec = np.asarray([float(i.replace('[', '').replace(',','').replace(']','')) for i in public_trans_vec if i != ']'])
#    124
#    125                                               # make copy of the SIR matrices
#    126         1        396.0    396.0      0.0      SIR_sim = SIR.copy()
#    127         1         19.0     19.0      0.0      SIR_nsim = SIR_n.copy()
#    128
#    129                                               # run model
#    130                                               #print(SIR_sim.sum(axis=0).sum() == N_k.sum())
#    131         1          1.0      1.0      0.0      infected_pop_norm = []
#    132         1          1.0      1.0      0.0      susceptible_pop_norm = []
#    133         1          0.0      0.0      0.0      recovered_pop_norm = []
#    134         1          2.0      2.0      0.0      days = args.days
#    135       101         95.0      0.9      0.0      for time_step in range(days):
#    136       100     873175.0   8731.8     23.8          infected_mat = np.array([SIR_nsim[:,1],]*locs_len).transpose()
#    137       100    1692983.0  16929.8     46.2          OD_infected = np.round(OD*infected_mat)
#    138       100     285348.0   2853.5      7.8          inflow_infected = OD_infected.sum(axis=0)
#    139       100       4734.0     47.3      0.1          inflow_infected = np.round(inflow_infected*public_trans_vec[time_step])
#    140                                                   #print('total infected inflow: ', inflow_infected.sum())
#    141       100     310654.0   3106.5      8.5          new_infect = beta_vec*SIR_sim[:, 0]*inflow_infected/(N_k + OD.sum(axis=0))
#    142       100       1416.0     14.2      0.0          new_recovered = gamma_vec*SIR_sim[:, 1]
#    143       100       1687.0     16.9      0.0          new_infect = np.where(new_infect>SIR_sim[:, 0], SIR_sim[:, 0], new_infect)
#    144       100       1132.0     11.3      0.0          SIR_sim[:, 0] = SIR_sim[:, 0] - new_infect
#    145       100       1027.0     10.3      0.0          SIR_sim[:, 1] = SIR_sim[:, 1] + new_infect - new_recovered
#    146       100        700.0      7.0      0.0          SIR_sim[:, 2] = SIR_sim[:, 2] + new_recovered
#    147       100       2636.0     26.4      0.1          SIR_sim = np.where(SIR_sim<0,0,SIR_sim)
#    148                                                   # recompute the normalized SIR matrix
#    149       100       5747.0     57.5      0.2          row_sums = SIR_sim.sum(axis=1)
#    150       100       2496.0     25.0      0.1          SIR_nsim = SIR_sim / row_sums[:, np.newaxis]
#    151       100       2611.0     26.1      0.1          S = SIR_sim[:,0].sum()/N_k.sum()
#    152       100        986.0      9.9      0.0          I = SIR_sim[:,1].sum()/N_k.sum()
#    153       100       1007.0     10.1      0.0          R = SIR_sim[:,2].sum()/N_k.sum()
#    154                                                   #print(S, I, R, (S+I+R)*N_k.sum(), N_k.sum())
#    155                                                   #print('\n')
#    156       100         77.0      0.8      0.0          infected_pop_norm.append(I)
#    157       100         69.0      0.7      0.0          susceptible_pop_norm.append(S)
#    158       100         49.0      0.5      0.0          recovered_pop_norm.append(R)
#    159
#    160         1     115055.0 115055.0      3.1      graphing_function(args, days, (susceptible_pop_norm, infected_pop_norm, recovered_pop_norm))

# %%
# %lprun -f covid_sim_serial covid_sim_serial(args3)

# %% [raw]
# Timer unit: 1e-06 s
#
# Total time: 11.3051 s
# File: /Users/sree/.ipython/cython/_cython_magic_fc024b63ed9cd3c1a2712e2c40b2da82.pyx
# Function: covid_sim_serial at line 162
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    162                                           def covid_sim_serial(args):
#    163         5         18.0      3.6      0.0      for i in range(args.randomize):
#    164         4   11305129.0 2826282.2    100.0          covid_sim(args)

# %%
# %lprun -f multiprocess multiprocess(args3)

# %% [raw]
# Timer unit: 1e-06 s
#
# Total time: 8.69907 s
# File: /Users/sree/.ipython/cython/_cython_magic_fc024b63ed9cd3c1a2712e2c40b2da82.pyx
# Function: multiprocess at line 60
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     60                                           def multiprocess(args):
#     61
#     62         1          2.0      2.0      0.0      chunks = []
#     63         1          2.0      2.0      0.0      num_procs = args.randomize
#     64         5          2.0      0.4      0.0      for _ in range(num_procs):
#     65         4          2.0      0.5      0.0          d = dict()
#     66         4          1.0      0.2      0.0          d['origin_matrix_path'] = args.origin_matrix_path
#     67         4         31.0      7.8      0.0          d['thresh1'] = np.random.randint(0, 350)
#     68         4          9.0      2.2      0.0          d['thresh2'] = np.random.randint(d['thresh1'], 700)
#     69         4          8.0      2.0      0.0          d['infection_magnitude'] = np.random.randint(5, 15)
#     70         4          2.0      0.5      0.0          d['beta'] = args.beta
#     71         4          3.0      0.8      0.0          d['gamma'] = args.gamma
#     72         4          9.0      2.2      0.0          d['public_trans'] = np.random.randint(1, 7) * 0.1
#     73         4        200.0     50.0      0.0          d['public_trans_vec'] = np.asarray([i.replace('[', '').replace(',','').replace(']','') for i in args.public_trans_vec])
#     74         4          4.0      1.0      0.0          d['days'] = args.days
#     75         4         13.0      3.2      0.0          d['fig_name'] = 'public_trans_{:0.1f}_({}, {})_inf_{}'.format(d['public_trans'], d['thresh1'], d['thresh2'], d['infection_magnitude'])
#     76         4          3.0      0.8      0.0          d['loading'] = args.loading
#     77         4          6.0      1.5      0.0          d = objdict(d)
#     78         4          3.0      0.8      0.0          chunks.append(d)
#     79
#     80         1      35010.0  35010.0      0.4      with Pool(num_procs) as p:
#     81         1    8662532.0 8662532.0     99.6          p.map(covid_sim, chunks)
#     82
#     83         1       1231.0   1231.0      0.0      p.join()

# %% [markdown]
# Using feature for loading, using Cython and removing tqdm provided a time reduction for both serial and parallel processes.

# %% [markdown]
# ### Cython - with types specified and multiprocessing

# %%
# %load_ext Cython
# %matplotlib inline
# Out:
# The Cython extension is already loaded. To reload it, use:
#   %reload_ext Cython

# %%
# %%cython
#
# # cython: profile=True
# # cython: linetrace=True
# # cython: binding=True
# # distutils: define_macros=CYTHON_TRACE_NOGIL=1
#
# import numpy as np
# from tqdm import tqdm
# import argparse
# from multiprocessing import cpu_count
# from functools import partial
# from multiprocessing.pool import Pool
# import pandas as pd
# cimport numpy as np
#
# def graphing_function(np.ndarray[np.float64_t, ndim=1] infected_pop_norm,
#                       np.ndarray[np.float64_t, ndim=1] susceptible_pop_norm,
#                       np.ndarray[np.float64_t, ndim=1] recovered_pop_norm,
#                       np.ndarray[np.float64_t, ndim=1] public_trans_vec,
#                       int days,
#                       fig_name):
#     import matplotlib.pyplot as plt
#     # plot results and save the plot
#     fig = plt.figure()
#     ax = plt.axes()
#     ax.spines['right'].set_visible(False)
#     ax.spines['top'].set_visible(False)
#     ax.spines['left'].set_visible(False)
#     ax.plot(np.arange(days), susceptible_pop_norm, label='Susceptible', color='#4aa5f0', linewidth=2)
#     ax.plot(np.arange(days), infected_pop_norm, label='Infected', color='#f03737', linewidth=2)
#     ax.plot(np.arange(days), recovered_pop_norm, label='Recovered', color='#82e88a', linewidth=2)
#     ax.plot(np.arange(days), public_trans_vec, '--', label='Transit', color='k', linewidth=2)
#     ax.legend(frameon=False, loc='center left', bbox_to_anchor=(1.01, 0.5))
#     ax.set_xlabel("Days")
#     ax.set_ylabel("Share of Population")
#     if fig_name:
#         ax.figure.savefig('figures/' + fig_name + '.png')
#     else:
#         ax.figure.savefig('figures/sir_plot.png')
#     # plt.show()
#     plt.close()
#
# # Convenience function: access Python dict keys as dict.key instead of dict['key']
# class objdict(dict):
#     def __getattr__(self, name):
#         if name in self:
#             return self[name]
#         else:
#             raise AttributeError("No such attribute: " + name)
#
#     def __setattr__(self, name, value):
#         self[name] = value
#
#     def __delattr__(self, name):
#         if name in self:
#             del self[name]
#         else:
#             raise AttributeError("No such attribute: " + name)
#
# # Run n simulations in parallel: for each run, parameters are randomly sampled from an interval
# # NOTE: Are these intervals reasonable?
# def multiprocess(args):
#
#     chunks = []
#     num_procs = args.randomize
#     for _ in range(num_procs):
#         d = dict()
#         d['origin_matrix_path'] = args.origin_matrix_path
#         d['thresh1'] = np.random.randint(0, 350)
#         d['thresh2'] = np.random.randint(d['thresh1'], 700)
#         d['infection_magnitude'] = np.random.randint(5, 15)
#         d['beta'] = args.beta
#         d['gamma'] = args.gamma
#         d['public_trans'] = np.random.randint(1, 7) * 0.1
#         d['public_trans_vec'] = np.asarray([float(i.replace('[', '').replace(',','').replace(']','')) for i in args.public_trans_vec])
#         d['days'] = args.days
#         d['fig_name'] = 'public_trans_{:0.1f}_({}, {})_inf_{}'.format(d['public_trans'], d['thresh1'], d['thresh2'], d['infection_magnitude'])
#         d['loading'] = args.loading
#         d = objdict(d)
#         chunks.append(d)
#
#     with Pool(num_procs) as p:
#         p.map(covid_sim, chunks)
#
#     p.join()
#
# def covid_sim(args):
#     # Read in origin-destination flow matrix
#     cdef np.ndarray[np.float64_t, ndim=2] OD, SIR, SIR_n, SIR_sim, SIR_nsim, infected_mat, OD_infected
#     cdef np.ndarray[np.float64_t, ndim=1] N_k, first_infections, row_sums, beta_vec, gamma_vec, inflow_infected, new_infect, new_recovered #, public_trans_vec
#     cdef int locs_len, time_step
#     cdef np.float64_t R0, S, I, R
#     cdef np.ndarray[np.float64_t, ndim=1] infected_pop_norm, susceptible_pop_norm, recovered_pop_norm
#
#     if args.loading != 0:
#         OD = pd.read_csv('data/nyc_od.csv', header=None, dtype=np.float64).to_numpy()
#     else:
#         OD = np.genfromtxt(args.origin_matrix_path, delimiter=',')
#
#     # initialize the population vector from the origin-destination flow matrix
#     N_k = np.abs(np.diagonal(OD) + OD.sum(axis=0) - OD.sum(axis=1))
#     locs_len = len(N_k)                 # number of locations
#     SIR = np.zeros(shape=(locs_len, 3)) # make a numpy array with 3 columns for keeping track of the S, I, R groups
#     SIR[:,0] = N_k                      # initialize the S group with the respective populations
#     thresh1 = args.thresh1
#     thresh2 = args.thresh2
#     first_infections = np.where((thresh1 <= SIR[:, 0]) & (SIR[:, 0] <= thresh2), np.random.randint(1, args.infection_magnitude), 0).astype(np.float64)   # for demo purposes, randomly introduce infections
#     # NOTE: this is arbitrary but not actually random....
#     SIR[:, 0] = SIR[:, 0] - first_infections
#     SIR[:, 1] = SIR[:, 1] + first_infections                           # move infections to the I group
#
#     # row normalize the SIR matrix for keeping track of group proportions
#     row_sums = SIR.sum(axis=1)
#     SIR_n = SIR / row_sums[:, np.newaxis]
#
#     # initialize parameters
#     beta = args.beta
#     gamma = args.gamma
#     public_trans = args.public_trans                                 # alpha
#     R0 = beta/gamma
#     beta_vec = np.random.gamma(beta, 2, locs_len)
#     gamma_vec = np.full(locs_len, gamma)
#     public_trans_vec = args.public_trans_vec
#     if isinstance(public_trans_vec[0], str):
#         public_trans_vec = np.asarray([float(i.replace('[', '').replace(',','').replace(']','')) for i in public_trans_vec])
#
#     fig_name = args.fig_name
#
#     # make copy of the SIR matrices
#     SIR_sim = SIR.copy()
#     SIR_nsim = SIR_n.copy()
#
#     # run model
#     #print(SIR_sim.sum(axis=0).sum() == N_k.sum())
#     days = args.days
#     infected_pop_norm = np.zeros(days)
#     susceptible_pop_norm = np.zeros(days)
#     recovered_pop_norm = np.zeros(days)
#     for time_step in tqdm(range(days)):
#         infected_mat = np.array([SIR_nsim[:,1],]*locs_len).transpose()
#         OD_infected = np.round(OD*infected_mat)
#         inflow_infected = OD_infected.sum(axis=0)
#         inflow_infected = np.round(inflow_infected*public_trans_vec[time_step])
#         #print('total infected inflow: ', inflow_infected.sum())
#         new_infect = beta_vec*SIR_sim[:, 0]*inflow_infected/(N_k + OD.sum(axis=0))
#         new_recovered = gamma_vec*SIR_sim[:, 1]
#         new_infect = np.where(new_infect>SIR_sim[:, 0], SIR_sim[:, 0], new_infect)
#         SIR_sim[:, 0] = SIR_sim[:, 0] - new_infect
#         SIR_sim[:, 1] = SIR_sim[:, 1] + new_infect - new_recovered
#         SIR_sim[:, 2] = SIR_sim[:, 2] + new_recovered
#         SIR_sim = np.where(SIR_sim<0,0,SIR_sim)
#         # recompute the normalized SIR matrix
#         row_sums = SIR_sim.sum(axis=1)
#         SIR_nsim = SIR_sim / row_sums[:, np.newaxis]
#         S = SIR_sim[:,0].sum()/N_k.sum()
#         I = SIR_sim[:,1].sum()/N_k.sum()
#         R = SIR_sim[:,2].sum()/N_k.sum()
#         #print(S, I, R, (S+I+R)*N_k.sum(), N_k.sum())
#         #print('\n')
#         infected_pop_norm[time_step] = I
#         susceptible_pop_norm[time_step] = S
#         recovered_pop_norm[time_step] = R
#
#     graphing_function(infected_pop_norm, susceptible_pop_norm, recovered_pop_norm, public_trans_vec, days, fig_name)
#
# def covid_sim_serial(args):
#     for i in range(args.randomize):
#         covid_sim(args)

# %%
# %lprun -f covid_sim_serial covid_sim_serial(args3)
# Out:
# 100%|██████████| 100/100 [00:02<00:00, 34.43it/s]
# 100%|██████████| 100/100 [00:02<00:00, 34.65it/s]
# 100%|██████████| 100/100 [00:02<00:00, 34.45it/s]
# 100%|██████████| 100/100 [00:02<00:00, 34.74it/s]

# %% [raw]
# Timer unit: 1e-06 s
#
# Total time: 15.5166 s
# File: /Users/sree/.ipython/cython/_cython_magic_7544b9454c9c3394ec15c2682b46261f.pyx
# Function: covid_sim_serial at line 166
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    166                                           def covid_sim_serial(args):
#    167         5         14.0      2.8      0.0      for i in range(args.randomize):
#    168         4   15516591.0 3879147.8    100.0          covid_sim(args)

# %%
# %lprun -f multiprocess multiprocess(args3)
# Out:
# 100%|██████████| 100/100 [00:09<00:00, 10.20it/s]
# 100%|██████████| 100/100 [00:09<00:00, 10.21it/s]

# %% [raw]
# Timer unit: 1e-06 s
#
# Total time: 12.1902 s
# File: /Users/sree/.ipython/cython/_cython_magic_7544b9454c9c3394ec15c2682b46261f.pyx
# Function: multiprocess at line 62
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     62                                           def multiprocess(args):
#     63
#     64         1          1.0      1.0      0.0      chunks = []
#     65         1          2.0      2.0      0.0      num_procs = args.randomize
#     66         5          5.0      1.0      0.0      for _ in range(num_procs):
#     67         4          0.0      0.0      0.0          d = dict()
#     68         4          2.0      0.5      0.0          d['origin_matrix_path'] = args.origin_matrix_path
#     69         4         31.0      7.8      0.0          d['thresh1'] = np.random.randint(0, 350)
#     70         4          9.0      2.2      0.0          d['thresh2'] = np.random.randint(d['thresh1'], 700)
#     71         4         10.0      2.5      0.0          d['infection_magnitude'] = np.random.randint(5, 15)
#     72         4          1.0      0.2      0.0          d['beta'] = args.beta
#     73         4          4.0      1.0      0.0          d['gamma'] = args.gamma
#     74         4         11.0      2.8      0.0          d['public_trans'] = np.random.randint(1, 7) * 0.1
#     75         4        229.0     57.2      0.0          d['public_trans_vec'] = np.asarray([float(i.replace('[', '').replace(',','').replace(']','')) for i in args.public_trans_vec])
#     76         4          3.0      0.8      0.0          d['days'] = args.days
#     77         4         14.0      3.5      0.0          d['fig_name'] = 'public_trans_{:0.1f}_({}, {})_inf_{}'.format(d['public_trans'], d['thresh1'], d['thresh2'], d['infection_magnitude'])
#     78         4          4.0      1.0      0.0          d['loading'] = args.loading
#     79         4          6.0      1.5      0.0          d = objdict(d)
#     80         4          2.0      0.5      0.0          chunks.append(d)
#     81
#     82         1      24593.0  24593.0      0.2      with Pool(num_procs) as p:
#     83         1   12164528.0 12164528.0     99.8          p.map(covid_sim, chunks)
#     84
#     85         1        775.0    775.0      0.0      p.join()
